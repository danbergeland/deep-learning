# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
for label, review in zip(labels,reviews):
    for word in str.split(review):
        if label == 'NEGATIVE':
            negative_counts[word] += 1
        else:
            positive_counts[word] += 1
        total_counts[word] += 1

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('the', 173324),
#  ('.', 159654),
#  ('and', 89722),
#  ('a', 83688),
#  ('of', 76855),
#  ('to', 66746),
#  ('is', 57245),
#  ('in', 50215),
#  ('br', 49235),
#  ('it', 48025),
#  ('i', 40743),
#  ('that', 35630),
#  ('this', 35080),
#  ('s', 33815),
#  ('as', 26308),
#  ('with', 23247),
#  ('for', 22416),
#  ('was', 21917),
#  ('film', 20937),
#  ('but', 20822),
#  ('movie', 19074),
#  ('his', 17227),
#  ('on', 17008),
#  ('you', 16681),
#  ('he', 16282),
#  ('are', 14807),
#  ('not', 14272),
#  ('t', 13720),
#  ('one', 13655),
#  ('have', 12587),
#  ('be', 12416),
#  ('by', 11997),
#  ('all', 11942),
#  ('who', 11464),
#  ('an', 11294),
#  ('at', 11234),
#  ('from', 10767),
#  ('her', 10474),
#  ('they', 9895),
#  ('has', 9186),
#  ('so', 9154),
#  ('like', 9038),
#  ('about', 8313),
#  ('very', 8305),
#  ('out', 8134),
#  ('there', 8057),
#  ('she', 7779),
#  ('what', 7737),
#  ('or', 7732),
#  ('good', 7720),
#  ('more', 7521),
#  ('when', 7456),
#  ('some', 7441),
#  ('if', 7285),
#  ('just', 7152),
#  ('can', 7001),
#  ('story', 6780),
#  ('time', 6515),
#  ('my', 6488),
#  ('great', 6419),
#  ('well', 6405),
#  ('up', 6321),
#  ('which', 6267),
#  ('their', 6107),
#  ('see', 6026),
#  ('also', 5550),
#  ('we', 5531),
#  ('really', 5476),
#  ('would', 5400),
#  ('will', 5218),
#  ('me', 5167),
#  ('had', 5148),
#  ('only', 5137),
#  ('him', 5018),
#  ('even', 4964),
#  ('most', 4864),
#  ('other', 4858),
#  ('were', 4782),
#  ('first', 4755),
#  ('than', 4736),
#  ('much', 4685),
#  ('its', 4622),
#  ('no', 4574),
#  ('into', 4544),
#  ('people', 4479),
#  ('best', 4319),
#  ('love', 4301),
#  ('get', 4272),
#  ('how', 4213),
#  ('life', 4199),
#  ('been', 4189),
#  ('because', 4079),
#  ('way', 4036),
#  ('do', 3941),
#  ('made', 3823),
#  ('films', 3813),
#  ('them', 3805),
#  ('after', 3800),
#  ('many', 3766),
#  ('two', 3733),
#  ('too', 3659),
#  ('think', 3655),
#  ('movies', 3586),
#  ('characters', 3560),
#  ('character', 3514),
#  ('don', 3468),
#  ('man', 3460),
#  ('show', 3432),
#  ('watch', 3424),
#  ('seen', 3414),
#  ('then', 3358),
#  ('little', 3341),
#  ('still', 3340),
#  ('make', 3303),
#  ('could', 3237),
#  ('never', 3226),
#  ('being', 3217),
#  ('where', 3173),
#  ('does', 3069),
#  ('over', 3017),
#  ('any', 3002),
#  ('while', 2899),
#  ('know', 2833),
#  ('did', 2790),
#  ('years', 2758),
#  ('here', 2740),
#  ('ever', 2734),
#  ('end', 2696),
#  ('these', 2694),
#  ('such', 2590),
#  ('real', 2568),
#  ('scene', 2567),
#  ('back', 2547),
#  ('those', 2485),
#  ('though', 2475),
#  ('off', 2463),
#  ('new', 2458),
#  ('your', 2453),
#  ('go', 2440),
#  ('acting', 2437),
#  ('plot', 2432),
#  ('world', 2429),
#  ('scenes', 2427),
#  ('say', 2414),
#  ('through', 2409),
#  ('makes', 2390),
#  ('better', 2381),
#  ('now', 2368),
#  ('work', 2346),
#  ('young', 2343),
#  ('old', 2311),
#  ('ve', 2307),
#  ('find', 2272),
#  ('both', 2248),
#  ('before', 2177),
#  ('us', 2162),
#  ('again', 2158),
#  ('series', 2153),
#  ('quite', 2143),
#  ('something', 2135),
#  ('cast', 2133),
#  ('should', 2121),
#  ('part', 2098),
#  ('always', 2088),
#  ('lot', 2087),
#  ('another', 2075),
#  ('actors', 2047),
#  ('director', 2040),
#  ('family', 2032),
#  ('between', 2016),
#  ('own', 2016),
#  ('m', 1998),
#  ('may', 1997),
#  ('same', 1972),
#  ('role', 1967),
#  ('watching', 1966),
#  ('every', 1954),
#  ('funny', 1953),
#  ('doesn', 1935),
#  ('performance', 1928),
#  ('few', 1918),
#  ('bad', 1907),
#  ('look', 1900),
#  ('re', 1884),
#  ('why', 1855),
#  ('things', 1849),
#  ('times', 1832),
#  ('big', 1815),
#  ('however', 1795),
#  ('actually', 1790),
#  ('action', 1789),
#  ('going', 1783),
#  ('bit', 1757),
#  ('comedy', 1742),
#  ('down', 1740),
#  ('music', 1738),
#  ('must', 1728),
#  ('take', 1709),
#  ('saw', 1692),
#  ('long', 1690),
#  ('right', 1688),
#  ('fun', 1686),
#  ('fact', 1684),
#  ('excellent', 1683),
#  ('around', 1674),
#  ('didn', 1672),
#  ('without', 1671),
#  ('thing', 1662),
#  ('thought', 1639),
#  ('got', 1635),
#  ('each', 1630),
#  ('day', 1614),
#  ('feel', 1597),
#  ('seems', 1596),
#  ('come', 1594),
#  ('done', 1586),
#  ('beautiful', 1580),
#  ('especially', 1572),
#  ('played', 1571),
#  ('almost', 1566),
#  ('want', 1562),
#  ('yet', 1556),
#  ('give', 1553),
#  ('pretty', 1549),
#  ('last', 1543),
#  ('since', 1519),
#  ('different', 1504),
#  ('although', 1501),
#  ('gets', 1490),
#  ('true', 1487),
#  ('interesting', 1481),
#  ('job', 1470),
#  ('enough', 1455),
#  ('our', 1454),
#  ('shows', 1447),
#  ('horror', 1441),
#  ('woman', 1439),
#  ('tv', 1400),
#  ('probably', 1398),
#  ('father', 1395),
#  ('original', 1393),
#  ('girl', 1390),
#  ('point', 1379),
#  ('plays', 1378),
#  ('wonderful', 1372),
#  ('course', 1358),
#  ('far', 1358),
#  ('john', 1350),
#  ('rather', 1340),
#  ('isn', 1328),
#  ('ll', 1326),
#  ('later', 1324),
#  ('dvd', 1324),
#  ('war', 1310),
#  ('whole', 1310),
#  ('d', 1307),
#  ('away', 1306),
#  ('found', 1306),
#  ('screen', 1305),
#  ('nothing', 1300),
#  ('year', 1297),
#  ('once', 1296),
#  ('hard', 1294),
#  ('together', 1280),
#  ('am', 1277),
#  ('set', 1277),
#  ('having', 1266),
#  ('making', 1265),
#  ('place', 1263),
#  ('comes', 1260),
#  ('might', 1260),
#  ('sure', 1253),
#  ('american', 1248),
#  ('play', 1245),
#  ('kind', 1244),
#  ('takes', 1242),
#  ('perfect', 1242),
#  ('performances', 1237),
#  ('himself', 1230),
#  ('worth', 1221),
#  ('everyone', 1221),
#  ('anyone', 1214),
#  ('actor', 1203),
#  ('three', 1201),
#  ('wife', 1196),
#  ('classic', 1192),
#  ('goes', 1186),
#  ('ending', 1178),
#  ('version', 1168),
#  ('star', 1149),
#  ('enjoy', 1146),
#  ('book', 1142),
#  ('nice', 1132),
#  ('everything', 1128),
#  ('during', 1124),
#  ('put', 1118),
#  ('seeing', 1111),
#  ('least', 1102),
#  ('house', 1100),
#  ('high', 1095),
#  ('watched', 1094),
#  ('men', 1087),
#  ('loved', 1087),
#  ('night', 1082),
#  ('anything', 1075),
#  ('guy', 1071),
#  ('believe', 1071),
#  ('top', 1063),
#  ('amazing', 1058),
#  ('hollywood', 1056),
#  ('looking', 1053),
#  ('main', 1044),
#  ('definitely', 1043),
#  ('gives', 1031),
#  ('home', 1029),
#  ('seem', 1028),
#  ('episode', 1023),
#  ('sense', 1020),
#  ('audience', 1020),
#  ('truly', 1017),
#  ('special', 1011),
#  ('fan', 1009),
#  ('second', 1009),
#  ('short', 1009),
#  ('mind', 1005),
#  ('human', 1001),
#  ('recommend', 999),
#  ('full', 996),
#  ('black', 995),
#  ('help', 991),
#  ('along', 989),
#  ('trying', 987),
#  ('small', 986),
#  ('death', 985),
#  ('friends', 981),
#  ('remember', 974),
#  ('often', 970),
#  ('said', 966),
#  ('favorite', 962),
#  ('heart', 959),
#  ('early', 957),
#  ('left', 956),
#  ('until', 955),
#  ('script', 954),
#  ('let', 954),
#  ('maybe', 937),
#  ('today', 936),
#  ('live', 934),
#  ('less', 934),
#  ('moments', 933),
#  ('others', 929),
#  ('brilliant', 926),
#  ('shot', 925),
#  ('liked', 923),
#  ('become', 916),
#  ('won', 915),
#  ('used', 910),
#  ('style', 907),
#  ('mother', 895),
#  ('lives', 894),
#  ('came', 893),
#  ('stars', 890),
#  ('cinema', 889),
#  ('looks', 885),
#  ('perhaps', 884),
#  ('read', 882),
#  ('enjoyed', 879),
#  ('boy', 875),
#  ('drama', 873),
#  ('highly', 871),
#  ('given', 870),
#  ('playing', 867),
#  ('use', 864),
#  ('next', 859),
#  ('women', 858),
#  ('fine', 857),
#  ('effects', 856),
#  ('kids', 854),
#  ('entertaining', 853),
#  ('need', 852),
#  ('line', 850),
#  ('works', 848),
#  ('someone', 847),
#  ('mr', 836),
#  ('simply', 835),
#  ('picture', 833),
#  ('children', 833),
#  ('face', 831),
#  ('friend', 831),
#  ('keep', 831),
#  ('dark', 830),
#  ('certainly', 828),
#  ('overall', 828),
#  ('minutes', 827),
#  ('wasn', 824),
#  ('history', 822),
#  ('finally', 820),
#  ('couple', 816),
#  ('against', 815),
#  ('son', 809),
#  ('understand', 808),
#  ('lost', 807),
#  ('michael', 805),
#  ('else', 801),
#  ('throughout', 798),
#  ('fans', 797),
#  ('city', 792),
#  ('reason', 789),
#  ('written', 787),
#  ('production', 787),
#  ('several', 784),
#  ('school', 783),
#  ('based', 781),
#  ('rest', 781),
#  ('try', 780),
#  ('dead', 776),
#  ('hope', 775),
#  ('strong', 768),
#  ('white', 765),
#  ('tell', 759),
#  ('itself', 758),
#  ('half', 753),
#  ('person', 749),
#  ('sometimes', 746),
#  ('past', 744),
#  ('start', 744),
#  ('genre', 743),
#  ('final', 739),
#  ('beginning', 739),
#  ('town', 738),
#  ('art', 734),
#  ('humor', 732),
#  ('game', 732),
#  ('yes', 731),
#  ('idea', 731),
#  ('late', 730),
#  ('becomes', 729),
#  ('despite', 729),
#  ('able', 726),
#  ('case', 726),
#  ('money', 723),
#  ('completely', 721),
#  ('child', 721),
#  ('side', 719),
#  ('camera', 716),
#  ('getting', 714),
#  ('instead', 712),
#  ('soon', 702),
#  ('under', 700),
#  ('viewer', 699),
#  ('age', 697),
#  ('days', 696),
#  ('stories', 696),
#  ('simple', 694),
#  ('felt', 694),
#  ('roles', 693),
#  ('video', 688),
#  ('name', 683),
#  ('either', 683),
#  ('doing', 677),
#  ('turns', 674),
#  ('close', 671),
#  ('wants', 671),
#  ('title', 669),
#  ('wrong', 668),
#  ('went', 666),
#  ('james', 665),
#  ('evil', 659),
#  ('episodes', 657),
#  ('budget', 657),
#  ('relationship', 655),
#  ('piece', 653),
#  ('fantastic', 653),
#  ('david', 651),
#  ('turn', 648),
#  ('murder', 646),
#  ('parts', 645),
#  ('brother', 644),
#  ('head', 643),
#  ('absolutely', 643),
#  ('experience', 642),
#  ('eyes', 641),
#  ('sex', 638),
#  ('called', 637),
#  ('direction', 637),
#  ('directed', 636),
#  ('lines', 634),
#  ('behind', 633),
#  ('sort', 632),
#  ('actress', 631),
#  ('lead', 630),
#  ('oscar', 628),
#  ('example', 627),
#  ('including', 627),
#  ('known', 625),
#  ('musical', 625),
#  ('chance', 621),
#  ('score', 620),
#  ('hit', 619),
#  ('feeling', 619),
#  ('already', 619),
#  ('voice', 615),
#  ('moment', 612),
#  ('living', 612),
#  ('low', 610),
#  ('supporting', 610),
#  ('ago', 609),
#  ('themselves', 608),
#  ('hilarious', 605),
#  ('reality', 605),
#  ('jack', 604),
#  ('told', 603),
#  ('hand', 601),
#  ('moving', 600),
#  ('dialogue', 600),
#  ('quality', 600),
#  ('happy', 599),
#  ('song', 599),
#  ('matter', 598),
#  ('paul', 598),
#  ('light', 594),
#  ('future', 593),
#  ('entire', 592),
#  ('finds', 591),
#  ('gave', 589),
#  ('laugh', 587),
#  ('released', 586),
#  ('expect', 584),
#  ('fight', 581),
#  ('particularly', 580),
#  ('cinematography', 579),
#  ('police', 579),
#  ('type', 578),
#  ('sound', 578),
#  ('whose', 578),
#  ('enjoyable', 573),
#  ('view', 573),
#  ('number', 572),
#  ('romantic', 572),
#  ('daughter', 572),
#  ('husband', 572),
#  ('documentary', 571),
#  ('self', 570),
#  ('superb', 569),
#  ('robert', 569),
#  ('modern', 569),
#  ('took', 569),
#  ('mean', 566),
#  ('shown', 563),
#  ('coming', 561),
#  ('important', 560),
#  ('leave', 559),
#  ('king', 559),
#  ('change', 558),
#  ('wanted', 555),
#  ('somewhat', 555),
#  ('tells', 554),
#  ('country', 552),
#  ('run', 552),
#  ('events', 552),
#  ('career', 552),
#  ('heard', 550),
#  ('season', 550),
#  ('girls', 549),
#  ('greatest', 549),
#  ('etc', 547),
#  ('care', 546),
#  ('starts', 545),
#  ('english', 542),
#  ('killer', 541),
#  ('guys', 540),
#  ('animation', 540),
#  ('totally', 540),
#  ('tale', 540),
#  ('usual', 539),
#  ('opinion', 535),
#  ('miss', 535),
#  ('violence', 531),
#  ('easy', 531),
#  ('songs', 530),
#  ('british', 528),
#  ('says', 526),
#  ('realistic', 525),
#  ('writing', 524),
#  ('writer', 522),
#  ('act', 522),
#  ('comic', 521),
#  ('thriller', 519),
#  ('television', 517),
#  ('power', 516),
#  ('ones', 515),
#  ('kid', 514),
#  ('york', 513),
#  ('novel', 513),
#  ('alone', 512),
#  ('problem', 512),
#  ('attention', 509),
#  ('involved', 508),
#  ('extremely', 507),
#  ('kill', 507),
#  ('seemed', 506),
#  ('french', 505),
#  ('hero', 505),
#  ('rock', 504),
#  ('stuff', 501),
#  ('wish', 499),
#  ('begins', 498),
#  ('taken', 497),
#  ('sad', 497),
#  ('ways', 496),
#  ('richard', 495),
#  ('knows', 494),
#  ('atmosphere', 493),
#  ('similar', 491),
#  ('taking', 491),
#  ('car', 491),
#  ('surprised', 491),
#  ('perfectly', 490),
#  ('george', 490),
#  ('team', 489),
#  ('eye', 489),
#  ('sequence', 489),
#  ('across', 489),
#  ('powerful', 488),
#  ('due', 488),
#  ('room', 488),
#  ('among', 488),
#  ('serious', 488),
#  ('b', 487),
#  ('order', 487),
#  ('cannot', 487),
#  ('strange', 487),
#  ('beauty', 486),
#  ('famous', 485),
#  ('tries', 484),
#  ('herself', 484),
#  ('myself', 484),
#  ('happened', 484),
#  ('class', 483),
#  ('four', 482),
#  ('cool', 481),
#  ('anyway', 479),
#  ('release', 479),
#  ('theme', 479),
#  ('opening', 478),
#  ('entertainment', 477),
#  ('slow', 475),
#  ('unique', 475),
#  ('exactly', 475),
#  ('ends', 475),
#  ('level', 474),
#  ('o', 474),
#  ('red', 474),
#  ('easily', 474),
#  ('interest', 472),
#  ('happen', 471),
#  ('crime', 470),
#  ('viewing', 468),
#  ('memorable', 467),
#  ('sets', 467),
#  ('group', 466),
#  ('stop', 466),
#  ('dance', 463),
#  ('message', 463),
#  ('working', 463),
#  ('sister', 463),
#  ('problems', 463),
#  ('knew', 462),
#  ('mystery', 461),
#  ('nature', 461),
#  ('bring', 460),
#  ('brought', 459),
#  ('believable', 459),
#  ('thinking', 459),
#  ('mostly', 458),
#  ('couldn', 457),
#  ('disney', 457),
#  ('society', 456),
#  ('lady', 455),
#  ('within', 455),
#  ('blood', 454),
#  ('parents', 453),
#  ('viewers', 453),
#  ('upon', 453),
#  ('meets', 452),
#  ('tom', 452),
#  ('peter', 452),
#  ('soundtrack', 452),
#  ('usually', 452),
#  ('form', 452),
#  ('local', 450),
#  ('follow', 448),
#  ('certain', 448),
#  ('whether', 447),
#  ('possible', 446),
#  ('emotional', 445),
#  ('above', 444),
#  ('de', 444),
#  ('killed', 444),
#  ('god', 443),
#  ('middle', 443),
#  ('happens', 442),
#  ('needs', 442),
#  ('flick', 442),
#  ('masterpiece', 441),
#  ('major', 440),
#  ('period', 440),
#  ('haven', 439),
#  ('named', 439),
#  ('particular', 438),
#  ('th', 438),
#  ('earth', 437),
#  ('feature', 437),
#  ('stand', 436),
#  ('words', 435),
#  ('typical', 435),
#  ('obviously', 433),
#  ('elements', 433),
#  ('romance', 431),
#  ('jane', 430),
#  ('yourself', 427),
#  ('showing', 427),
#  ('brings', 426),
#  ('fantasy', 426),
#  ('guess', 423),
#  ('america', 423),
#  ('unfortunately', 422),
#  ('huge', 422),
#  ('indeed', 421),
#  ('running', 421),
#  ('talent', 420),
#  ('stage', 419),
#  ('started', 418),
#  ('japanese', 417),
#  ('leads', 417),
#  ('sweet', 417),
#  ('poor', 416),
#  ('deal', 416),
#  ('incredible', 413),
#  ('personal', 413),
#  ('fast', 412),
#  ('became', 410),
#  ('deep', 410),
#  ('hours', 409),
#  ('giving', 408),
#  ('nearly', 408),
#  ('dream', 408),
#  ('clearly', 407),
#  ('turned', 407),
#  ('obvious', 406),
#  ('near', 406),
#  ('cut', 405),
#  ('surprise', 405),
#  ('era', 404),
#  ('body', 404),
#  ('five', 403),
#  ('hour', 403),
#  ('female', 403),
#  ('note', 399),
#  ('truth', 398),
#  ('learn', 398),
#  ('match', 397),
#  ('except', 397),
#  ('tony', 397),
#  ('feels', 397),
#  ('complete', 394),
#  ('clear', 394),
#  ('filmed', 394),
#  ('street', 393),
#  ('keeps', 393),
#  ('older', 393),
#  ('eventually', 393),
#  ('lots', 393),
#  ('buy', 392),
#  ('william', 391),
#  ('stewart', 391),
#  ('meet', 390),
#  ('fall', 390),
#  ('joe', 390),
#  ('talking', 389),
#  ('unlike', 389),
#  ('shots', 389),
#  ('rating', 389),
#  ('difficult', 389),
#  ('means', 388),
#  ('dramatic', 388),
#  ('appears', 386),
#  ('situation', 386),
#  ('subject', 386),
#  ('wonder', 386),
#  ('present', 386),
#  ('comments', 385),
#  ('sequences', 383),
#  ('lee', 383),
#  ('general', 383),
#  ('earlier', 382),
#  ('points', 382),
#  ('gone', 379),
#  ('check', 379),
#  ('suspense', 378),
#  ('recommended', 378),
#  ('ten', 378),
#  ('business', 377),
#  ('third', 377),
#  ('talk', 375),
#  ('beyond', 375),
#  ('leaves', 375),
#  ('portrayal', 374),
#  ('beautifully', 373),
#  ('bill', 372),
#  ('single', 372),
#  ('word', 371),
#  ('plenty', 371),
#  ('falls', 370),
#  ('whom', 370),
#  ('battle', 369),
#  ('figure', 369),
#  ('scary', 369),
#  ('non', 369),
#  ('return', 368),
#  ('using', 368),
#  ('doubt', 367),
#  ('add', 367),
#  ('solid', 366),
#  ('success', 366),
#  ('hear', 366),
#  ('jokes', 365),
#  ('political', 365),
#  ('touching', 365),
#  ('oh', 365),
#  ('boys', 364),
#  ('hell', 364),
#  ('awesome', 364),
#  ('recently', 362),
#  ('sexual', 362),
#  ('dog', 362),
#  ('please', 361),
#  ('features', 361),
#  ('wouldn', 361),
#  ('straight', 361),
#  ('setting', 360),
#  ('forget', 360),
#  ('lack', 360),
#  ('married', 359),
#  ('mark', 359),
#  ('social', 357),
#  ('interested', 356),
#  ('adventure', 356),
#  ('actual', 355),
#  ('sees', 355),
#  ('terrific', 355),
#  ('brothers', 355),
#  ('move', 354),
#  ('call', 354),
#  ('dr', 353),
#  ('theater', 353),
#  ('various', 353),
#  ('animated', 352),
#  ('western', 351),
#  ('space', 350),
#  ('baby', 350),
#  ('disappointed', 348),
#  ('leading', 348),
#  ('aren', 346),
#  ('portrayed', 346),
#  ('screenplay', 345),
#  ('smith', 345),
#  ('hate', 344),
#  ('towards', 344),
#  ('noir', 343),
#  ('outstanding', 342),
#  ('kelly', 342),
#  ('decent', 342),
#  ('directors', 341),
#  ('journey', 341),
#  ('effective', 340),
#  ('looked', 340),
#  ('none', 340),
#  ('mary', 339),
#  ('caught', 339),
#  ('storyline', 339),
#  ('cold', 339),
#  ('sci', 339),
#  ('fi', 339),
#  ('charming', 338),
#  ('rich', 338),
#  ('harry', 337),
#  ('manages', 337),
#  ('popular', 337),
#  ('rare', 337),
#  ('spirit', 336),
#  ('open', 335),
#  ('appreciate', 335),
#  ('basically', 334),
#  ('acted', 334),
#  ('moves', 334),
#  ('boring', 333),
#  ('deserves', 333),
#  ('mention', 333),
#  ('inside', 333),
#  ('subtle', 333),
#  ('century', 333),
#  ('pace', 333),
#  ('background', 332),
#  ('familiar', 332),
#  ('ben', 331),
#  ('creepy', 330),
#  ('supposed', 330),
#  ('secret', 329),
#  ('jim', 328),
#  ('die', 328),
#  ('effect', 327),
#  ('natural', 327),
#  ('question', 327),
#  ('impressive', 326),
#  ('language', 326),
#  ('rate', 326),
#  ('intelligent', 325),
#  ('saying', 325),
#  ('scott', 324),
#  ('material', 324),
#  ('realize', 324),
#  ('telling', 324),
#  ('singing', 323),
#  ('dancing', 322),
#  ('adult', 321),
#  ('imagine', 321),
#  ('visual', 321),
#  ('office', 320),
#  ('kept', 320),
#  ('uses', 319),
#  ('wait', 318),
#  ('stunning', 318),
#  ('pure', 318),
#  ('review', 317),
#  ('seriously', 317),
#  ('previous', 317),
#  ('copy', 317),
#  ('created', 316),
#  ('somehow', 316),
#  ('create', 316),
#  ('hot', 316),
#  ('reading', 316),
#  ('magic', 316),
#  ('escape', 315),
#  ('air', 315),
#  ('crazy', 315),
#  ('stay', 315),
#  ('frank', 315),
#  ('attempt', 315),
#  ('hands', 314),
#  ('filled', 313),
#  ('expected', 312),
#  ('surprisingly', 312),
#  ('average', 312),
#  ('complex', 311),
#  ('studio', 310),
#  ('quickly', 310),
#  ('successful', 310),
#  ('male', 309),
#  ('plus', 309),
#  ('co', 307),
#  ('exciting', 306),
#  ('following', 306),
#  ('images', 306),
#  ('minute', 306),
#  ('casting', 306),
#  ('follows', 305),
#  ('e', 305),
#  ('reasons', 305),
#  ('members', 305),
#  ('german', 305),
#  ('themes', 305),
#  ('edge', 304),
#  ('cute', 304),
#  ('touch', 304),
#  ('free', 304),
#  ('genius', 304),
#  ('outside', 303),
#  ('admit', 302),
#  ('younger', 302),
#  ('reviews', 302),
#  ('ok', 302),
#  ('odd', 301),
#  ('master', 301),
#  ('fighting', 301),
#  ('recent', 300),
#  ('comment', 300),
#  ('thanks', 300),
#  ('break', 300),
#  ('apart', 299),
#  ('emotions', 298),
#  ('begin', 298),
#  ('lovely', 298),
#  ('italian', 297),
#  ('doctor', 297),
#  ('party', 297),
#  ('south', 296),
#  ('sequel', 296),
#  ('la', 296),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('.', 670152),
#  ('the', 653556),
#  ('a', 317284),
#  ('and', 297540),
#  ('of', 276036),
#  ('to', 275896),
#  ('br', 210548),
#  ('is', 200332),
#  ('it', 193308),
#  ('i', 187520),
#  ('in', 175012),
#  ('this', 163680),
#  ('that', 150460),
#  ('s', 126184),
#  ('was', 105164),
#  ('movie', 99860),
#  ('for', 87708),
#  ('but', 87124),
#  ('with', 83512),
#  ('as', 82500),
#  ('t', 81444),
#  ('film', 76872),
#  ('you', 70196),
#  ('on', 68768),
#  ('not', 65416),
#  ('have', 60576),
#  ('are', 58492),
#  ('be', 58164),
#  ('he', 55424),
#  ('one', 52536),
#  ('they', 52044),
#  ('at', 49116),
#  ('his', 48588),
#  ('all', 48144),
#  ('so', 45852),
#  ('like', 44952),
#  ('there', 43100),
#  ('just', 42476),
#  ('by', 42196),
#  ('or', 41088),
#  ('an', 41064),
#  ('who', 39876),
#  ('from', 38924),
#  ('if', 38072),
#  ('about', 36244),
#  ('out', 35916),
#  ('what', 33688),
#  ('some', 33224),
#  ('no', 32572),
#  ('her', 31788),
#  ('even', 30748),
#  ('can', 30612),
#  ('has', 30416),
#  ('good', 29692),
#  ('bad', 29604),
#  ('would', 28144),
#  ('up', 27880),
#  ('only', 27124),
#  ('more', 26920),
#  ('when', 26904),
#  ('she', 25776),
#  ('really', 25048),
#  ('time', 24836),
#  ('had', 24568),
#  ('my', 24060),
#  ('were', 24004),
#  ('which', 23120),
#  ('very', 23056),
#  ('me', 22424),
#  ('see', 21808),
#  ('don', 21344),
#  ('we', 21312),
#  ('their', 21112),
#  ('do', 20944),
#  ('story', 20832),
#  ('than', 20732),
#  ('been', 20400),
#  ('much', 20312),
#  ('get', 20148),
#  ('because', 19864),
#  ('people', 19224),
#  ('then', 19044),
#  ('make', 18888),
#  ('how', 18752),
#  ('could', 18744),
#  ('any', 18632),
#  ('into', 18268),
#  ('made', 18164),
#  ('first', 17224),
#  ('other', 17220),
#  ('well', 17016),
#  ('too', 16696),
#  ('them', 16660),
#  ('plot', 16616),
#  ('movies', 16320),
#  ('acting', 16224),
#  ('will', 15972),
#  ('way', 15956),
#  ('most', 15676),
#  ('him', 15432),
#  ('after', 15352),
#  ('its', 14620),
#  ('think', 14572),
#  ('also', 14432),
#  ('characters', 14400),
#  ('off', 14268),
#  ('watch', 14200),
#  ('character', 14024),
#  ('did', 14024),
#  ('why', 13852),
#  ('being', 13572),
#  ('better', 13432),
#  ('know', 13336),
#  ('over', 13264),
#  ('seen', 13060),
#  ('ever', 13052),
#  ('never', 13036),
#  ('your', 12932),
#  ('where', 12876),
#  ('two', 12692),
#  ('little', 12384),
#  ('films', 12308),
#  ('here', 12108),
#  ('m', 12000),
#  ('nothing', 11960),
#  ('say', 11928),
#  ('end', 11816),
#  ('something', 11768),
#  ('should', 11680),
#  ('many', 11636),
#  ('does', 11484),
#  ('thing', 11464),
#  ('show', 11448),
#  ('ve', 11316),
#  ('scene', 11264),
#  ('scenes', 11140),
#  ('these', 10896),
#  ('go', 10868),
#  ('didn', 10584),
#  ('watching', 10560),
#  ('great', 10560),
#  ('re', 10480),
#  ('doesn', 10404),
#  ('through', 10240),
#  ('such', 10176),
#  ('man', 10064),
#  ('worst', 9920),
#  ('actually', 9796),
#  ('actors', 9748),
#  ('life', 9716),
#  ('back', 9696),
#  ('while', 9672),
#  ('director', 9620),
#  ('funny', 9344),
#  ('going', 9276),
#  ('still', 9132),
#  ('another', 9016),
#  ('look', 8988),
#  ('now', 8948),
#  ('old', 8860),
#  ('those', 8848),
#  ('real', 8680),
#  ('few', 8632),
#  ('love', 8608),
#  ('horror', 8600),
#  ('before', 8588),
#  ('want', 8564),
#  ('minutes', 8504),
#  ('pretty', 8460),
#  ('best', 8376),
#  ('though', 8364),
#  ('same', 8324),
#  ('script', 8296),
#  ('work', 8108),
#  ('every', 8100),
#  ('seems', 8092),
#  ('least', 8044),
#  ('enough', 7988),
#  ('down', 7952),
#  ('original', 7932),
#  ('guy', 7856),
#  ('got', 7808),
#  ('around', 7772),
#  ('part', 7768),
#  ('lot', 7568),
#  ('anything', 7496),
#  ('find', 7440),
#  ('new', 7416),
#  ('isn', 7396),
#  ('again', 7396),
#  ('point', 7380),
#  ('things', 7356),
#  ('fact', 7356),
#  ('give', 7292),
#  ('makes', 7256),
#  ('take', 7200),
#  ('thought', 7192),
#  ('d', 7080),
#  ('whole', 7072),
#  ('long', 7044),
#  ('years', 7036),
#  ('however', 6960),
#  ('gets', 6856),
#  ('making', 6780),
#  ('cast', 6776),
#  ('big', 6648),
#  ('might', 6632),
#  ('interesting', 6592),
#  ('money', 6552),
#  ('us', 6512),
#  ('right', 6500),
#  ('far', 6476),
#  ('quite', 6384),
#  ('without', 6380),
#  ('come', 6380),
#  ('almost', 6296),
#  ('ll', 6268),
#  ('action', 6264),
#  ('awful', 6228),
#  ('kind', 6156),
#  ('reason', 6136),
#  ('am', 6120),
#  ('looks', 6112),
#  ('must', 6088),
#  ('done', 6040),
#  ('comedy', 6016),
#  ('someone', 5960),
#  ('trying', 5944),
#  ('wasn', 5936),
#  ('poor', 5924),
#  ('boring', 5912),
#  ('instead', 5912),
#  ('saw', 5900),
#  ('away', 5876),
#  ('girl', 5852),
#  ('probably', 5776),
#  ('believe', 5736),
#  ('sure', 5732),
#  ('looking', 5720),
#  ('stupid', 5712),
#  ('anyone', 5672),
#  ('times', 5624),
#  ('world', 5616),
#  ('maybe', 5616),
#  ('rather', 5576),
#  ('terrible', 5564),
#  ('last', 5560),
#  ('may', 5560),
#  ('since', 5552),
#  ('let', 5540),
#  ('tv', 5528),
#  ('hard', 5496),
#  ('between', 5496),
#  ('waste', 5432),
#  ('woman', 5424),
#  ('feel', 5416),
#  ('effects', 5392),
#  ('half', 5364),
#  ('own', 5332),
#  ('young', 5268),
#  ('music', 5264),
#  ('idea', 5248),
#  ('sense', 5224),
#  ('bit', 5192),
#  ('having', 5120),
#  ('book', 5112),
#  ('found', 5068),
#  ('series', 5052),
#  ('put', 5052),
#  ('goes', 5024),
#  ('worse', 4996),
#  ('said', 4920),
#  ('comes', 4896),
#  ('role', 4888),
#  ('main', 4880),
#  ('else', 4796),
#  ('everything', 4788),
#  ('yet', 4784),
#  ('low', 4756),
#  ('screen', 4752),
#  ('supposed', 4744),
#  ('actor', 4740),
#  ('either', 4732),
#  ('ending', 4716),
#  ('budget', 4716),
#  ('audience', 4712),
#  ('set', 4708),
#  ('family', 4680),
#  ('left', 4676),
#  ('completely', 4672),
#  ('both', 4632),
#  ('wrong', 4620),
#  ('always', 4604),
#  ('course', 4592),
#  ('place', 4592),
#  ('seem', 4588),
#  ('watched', 4568),
#  ('day', 4528),
#  ('simply', 4520),
#  ('shot', 4504),
#  ('mean', 4468),
#  ('special', 4408),
#  ('dead', 4404),
#  ('three', 4376),
#  ('house', 4340),
#  ('oh', 4336),
#  ('night', 4332),
#  ('read', 4328),
#  ('less', 4268),
#  ('high', 4264),
#  ('year', 4256),
#  ('camera', 4244),
#  ('worth', 4228),
#  ('our', 4224),
#  ('try', 4204),
#  ('sex', 4184),
#  ('horrible', 4184),
#  ('video', 4172),
#  ('black', 4156),
#  ('couldn', 4144),
#  ('although', 4144),
#  ('once', 4132),
#  ('rest', 4088),
#  ('dvd', 4084),
#  ('line', 4072),
#  ('played', 4068),
#  ('fun', 4028),
#  ('during', 4024),
#  ('production', 4012),
#  ('everyone', 4008),
#  ('play', 3972),
#  ('mind', 3960),
#  ('version', 3956),
#  ('kids', 3956),
#  ('seeing', 3952),
#  ('american', 3920),
#  ('given', 3912),
#  ('used', 3876),
#  ('performance', 3872),
#  ('especially', 3852),
#  ('together', 3852),
#  ('tell', 3836),
#  ('women', 3832),
#  ('start', 3824),
#  ('need', 3820),
#  ('second', 3812),
#  ('each', 3800),
#  ('takes', 3800),
#  ('wife', 3776),
#  ('dialogue', 3768),
#  ('use', 3760),
#  ('problem', 3752),
#  ('star', 3736),
#  ('unfortunately', 3724),
#  ('himself', 3716),
#  ('doing', 3704),
#  ('death', 3688),
#  ('name', 3684),
#  ('lines', 3676),
#  ('killer', 3656),
#  ('getting', 3652),
#  ('help', 3620),
#  ('fan', 3608),
#  ('couple', 3608),
#  ('head', 3592),
#  ('crap', 3580),
#  ('guess', 3552),
#  ('piece', 3536),
#  ('nice', 3520),
#  ('different', 3512),
#  ('school', 3504),
#  ('later', 3500),
#  ('entire', 3476),
#  ('shows', 3440),
#  ('john', 3432),
#  ('next', 3432),
#  ('seemed', 3428),
#  ('short', 3428),
#  ('hollywood', 3400),
#  ('home', 3392),
#  ('true', 3384),
#  ('person', 3384),
#  ('absolutely', 3368),
#  ('sort', 3360),
#  ('care', 3356),
#  ('understand', 3344),
#  ('plays', 3340),
#  ('felt', 3336),
#  ('written', 3316),
#  ('title', 3312),
#  ('men', 3288),
#  ('until', 3284),
#  ('flick', 3264),
#  ('decent', 3260),
#  ('face', 3256),
#  ('friends', 3240),
#  ('stars', 3228),
#  ('job', 3228),
#  ('case', 3228),
#  ('itself', 3216),
#  ('yes', 3204),
#  ('perhaps', 3200),
#  ('wanted', 3188),
#  ('went', 3188),
#  ('called', 3184),
#  ('annoying', 3180),
#  ('ridiculous', 3160),
#  ('tries', 3160),
#  ('laugh', 3152),
#  ('evil', 3148),
#  ('along', 3144),
#  ('top', 3140),
#  ('hour', 3136),
#  ('full', 3132),
#  ('came', 3120),
#  ('writing', 3120),
#  ('keep', 3080),
#  ('totally', 3068),
#  ('playing', 3064),
#  ('god', 3060),
#  ('won', 3056),
#  ('guys', 3052),
#  ('already', 3048),
#  ('gore', 3028),
#  ('direction', 2992),
#  ('save', 2984),
#  ('lost', 2980),
#  ('example', 2976),
#  ('sound', 2968),
#  ('war', 2964),
#  ('attempt', 2940),
#  ('except', 2932),
#  ('car', 2932),
#  ('blood', 2928),
#  ('moments', 2928),
#  ('obviously', 2920),
#  ('act', 2916),
#  ('remember', 2912),
#  ('kill', 2908),
#  ('white', 2904),
#  ('truly', 2904),
#  ('father', 2904),
#  ('b', 2900),
#  ('thinking', 2880),
#  ('ok', 2864),
#  ('finally', 2864),
#  ('turn', 2844),
#  ('quality', 2804),
#  ('lack', 2792),
#  ('style', 2776),
#  ('wouldn', 2772),
#  ('cheap', 2764),
#  ('none', 2760),
#  ('please', 2744),
#  ('kid', 2744),
#  ('boy', 2740),
#  ('seriously', 2736),
#  ('lead', 2720),
#  ('dull', 2708),
#  ('children', 2704),
#  ('starts', 2700),
#  ('stuff', 2692),
#  ('hope', 2688),
#  ('looked', 2680),
#  ('recommend', 2676),
#  ('under', 2672),
#  ('killed', 2668),
#  ('run', 2668),
#  ('others', 2664),
#  ('enjoy', 2664),
#  ('myself', 2652),
#  ('etc', 2652),
#  ('girls', 2648),
#  ('against', 2648),
#  ('beginning', 2648),
#  ('obvious', 2640),
#  ('small', 2640),
#  ('hell', 2636),
#  ('slow', 2628),
#  ('hand', 2624),
#  ('lame', 2608),
#  ('wonder', 2608),
#  ('becomes', 2604),
#  ('picture', 2604),
#  ('based', 2600),
#  ('early', 2592),
#  ('behind', 2584),
#  ('poorly', 2576),
#  ('avoid', 2568),
#  ('complete', 2560),
#  ('apparently', 2560),
#  ('happens', 2556),
#  ('anyway', 2552),
#  ('classic', 2548),
#  ('several', 2544),
#  ('despite', 2540),
#  ('certainly', 2540),
#  ('episode', 2540),
#  ('often', 2524),
#  ('cut', 2520),
#  ('writer', 2520),
#  ('predictable', 2512),
#  ('gave', 2512),
#  ('mother', 2512),
#  ('become', 2508),
#  ('close', 2500),
#  ('fans', 2496),
#  ('saying', 2484),
#  ('scary', 2476),
#  ('live', 2472),
#  ('stop', 2472),
#  ('wants', 2468),
#  ('self', 2460),
#  ('mr', 2448),
#  ('jokes', 2444),
#  ('friend', 2444),
#  ('cannot', 2440),
#  ('overall', 2436),
#  ('cinema', 2416),
#  ('child', 2412),
#  ('silly', 2404),
#  ('beautiful', 2384),
#  ('human', 2380),
#  ('expect', 2376),
#  ('liked', 2372),
#  ('happened', 2368),
#  ('entertaining', 2360),
#  ('bunch', 2360),
#  ('final', 2352),
#  ('actress', 2352),
#  ('performances', 2336),
#  ('says', 2336),
#  ('turns', 2308),
#  ('humor', 2308),
#  ('eyes', 2304),
#  ('themselves', 2304),
#  ('hours', 2296),
#  ('happen', 2292),
#  ('basically', 2288),
#  ('days', 2288),
#  ('running', 2284),
#  ('involved', 2276),
#  ('disappointed', 2276),
#  ('call', 2276),
#  ('group', 2272),
#  ('directed', 2272),
#  ('fight', 2268),
#  ('daughter', 2264),
#  ('talking', 2264),
#  ('body', 2264),
#  ('sorry', 2260),
#  ('badly', 2260),
#  ('throughout', 2252),
#  ('viewer', 2252),
#  ('yourself', 2248),
#  ('extremely', 2248),
#  ('violence', 2244),
#  ('heard', 2244),
#  ('interest', 2244),
#  ('shots', 2236),
#  ('side', 2228),
#  ('word', 2224),
#  ('art', 2220),
#  ('possible', 2216),
#  ('dark', 2204),
#  ('game', 2204),
#  ('hero', 2200),
#  ('alone', 2196),
#  ('leave', 2188),
#  ('type', 2188),
#  ('son', 2188),
#  ('gives', 2184),
#  ('parts', 2184),
#  ('single', 2184),
#  ('started', 2180),
#  ('female', 2172),
#  ('mess', 2164),
#  ('voice', 2164),
#  ('rating', 2164),
#  ('town', 2160),
#  ('aren', 2160),
#  ('drama', 2152),
#  ('definitely', 2148),
#  ('unless', 2144),
#  ('review', 2136),
#  ('effort', 2132),
#  ('able', 2132),
#  ('weak', 2132),
#  ('took', 2124),
#  ('five', 2120),
#  ('non', 2120),
#  ('matter', 2116),
#  ('usually', 2116),
#  ('michael', 2112),
#  ('feeling', 2104),
#  ('huge', 2092),
#  ('sequel', 2088),
#  ('soon', 2084),
#  ('exactly', 2080),
#  ('past', 2076),
#  ('police', 2072),
#  ('turned', 2072),
#  ('tried', 2060),
#  ('talent', 2052),
#  ('middle', 2052),
#  ('genre', 2048),
#  ('zombie', 2040),
#  ('history', 2036),
#  ('ends', 2036),
#  ('straight', 2012),
#  ('coming', 2004),
#  ('opening', 2004),
#  ('serious', 2004),
#  ('moment', 2000),
#  ('sad', 1996),
#  ('lives', 1996),
#  ('particularly', 1992),
#  ('dialog', 1992),
#  ('editing', 1972),
#  ('clearly', 1968),
#  ('earth', 1964),
#  ('beyond', 1964),
#  ('taken', 1960),
#  ('cool', 1960),
#  ('dumb', 1956),
#  ('level', 1956),
#  ('okay', 1952),
#  ('major', 1948),
#  ('premise', 1940),
#  ('fast', 1940),
#  ('stories', 1936),
#  ('joke', 1936),
#  ('minute', 1932),
#  ('wasted', 1932),
#  ('rent', 1928),
#  ('mostly', 1928),
#  ('across', 1928),
#  ('late', 1924),
#  ('falls', 1924),
#  ('fails', 1924),
#  ('mention', 1912),
#  ('theater', 1900),
#  ('stay', 1888),
#  ('sometimes', 1888),
#  ('hit', 1872),
#  ('talk', 1868),
#  ('fine', 1868),
#  ('die', 1864),
#  ('pointless', 1860),
#  ('storyline', 1860),
#  ('taking', 1856),
#  ('order', 1848),
#  ('brother', 1844),
#  ('whatever', 1840),
#  ('told', 1840),
#  ('wish', 1832),
#  ('room', 1824),
#  ('appears', 1820),
#  ('career', 1820),
#  ('write', 1820),
#  ('husband', 1816),
#  ('known', 1816),
#  ('living', 1804),
#  ('ten', 1800),
#  ('sit', 1800),
#  ('words', 1796),
#  ('monster', 1792),
#  ('chance', 1792),
#  ('novel', 1776),
#  ('hate', 1776),
#  ('english', 1772),
#  ('add', 1772),
#  ('somehow', 1764),
#  ('strange', 1760),
#  ('actual', 1752),
#  ('imdb', 1752),
#  ('killing', 1748),
#  ('material', 1748),
#  ('total', 1748),
#  ('ones', 1748),
#  ('knew', 1744),
#  ('number', 1736),
#  ('king', 1736),
#  ('using', 1732),
#  ('lee', 1724),
#  ('giving', 1724),
#  ('shown', 1724),
#  ('power', 1724),
#  ('works', 1724),
#  ('possibly', 1720),
#  ('kept', 1720),
#  ('points', 1720),
#  ('four', 1716),
#  ('local', 1708),
#  ('usual', 1704),
#  ('including', 1700),
#  ('opinion', 1696),
#  ('ago', 1696),
#  ('problems', 1696),
#  ('nudity', 1692),
#  ('age', 1688),
#  ('due', 1684),
#  ('roles', 1680),
#  ('decided', 1676),
#  ('writers', 1676),
#  ('near', 1672),
#  ('flat', 1672),
#  ('easily', 1672),
#  ('murder', 1668),
#  ('experience', 1668),
#  ('reviews', 1664),
#  ('imagine', 1660),
#  ('feels', 1652),
#  ('plain', 1644),
#  ('somewhat', 1644),
#  ('class', 1640),
#  ('score', 1640),
#  ('whether', 1636),
#  ('song', 1636),
#  ('bring', 1636),
#  ('average', 1632),
#  ('otherwise', 1632),
#  ('whose', 1632),
#  ('pathetic', 1628),
#  ('knows', 1628),
#  ('zombies', 1628),
#  ('nearly', 1628),
#  ('cheesy', 1624),
#  ('cinematography', 1624),
#  ('upon', 1624),
#  ('city', 1620),
#  ('space', 1620),
#  ('credits', 1616),
#  ('james', 1612),
#  ('lots', 1612),
#  ('change', 1612),
#  ('nor', 1608),
#  ('entertainment', 1608),
#  ('wait', 1604),
#  ('released', 1600),
#  ('needs', 1596),
#  ('shame', 1592),
#  ('attention', 1584),
#  ('comments', 1576),
#  ('lady', 1572),
#  ('bored', 1572),
#  ('free', 1572),
#  ('expected', 1568),
#  ('needed', 1568),
#  ('clear', 1568),
#  ('view', 1564),
#  ('check', 1560),
#  ('doubt', 1560),
#  ('development', 1560),
#  ('figure', 1556),
#  ('mystery', 1556),
#  ('garbage', 1552),
#  ('excellent', 1552),
#  ('television', 1544),
#  ('sequence', 1544),
#  ('o', 1540),
#  ('sets', 1540),
#  ('potential', 1536),
#  ('laughable', 1536),
#  ('country', 1528),
#  ('light', 1528),
#  ('robert', 1528),
#  ('documentary', 1528),
#  ('reality', 1528),
#  ('general', 1524),
#  ('ask', 1524),
#  ('begin', 1520),
#  ('fall', 1520),
#  ('comic', 1520),
#  ('stand', 1516),
#  ('forced', 1516),
#  ('remake', 1516),
#  ('trash', 1516),
#  ('footage', 1516),
#  ('songs', 1512),
#  ('thriller', 1512),
#  ('gay', 1508),
#  ('within', 1508),
#  ('hardly', 1504),
#  ('above', 1500),
#  ('gone', 1500),
#  ('george', 1496),
#  ('sounds', 1492),
#  ('means', 1492),
#  ('david', 1488),
#  ('buy', 1488),
#  ('directing', 1488),
#  ('move', 1488),
#  ('forward', 1484),
#  ('rock', 1484),
#  ('important', 1484),
#  ('british', 1480),
#  ('hot', 1480),
#  ('haven', 1480),
#  ('filmed', 1480),
#  ('fake', 1476),
#  ('heart', 1476),
#  ('reading', 1476),
#  ('weird', 1472),
#  ('hear', 1472),
#  ('incredibly', 1472),
#  ('enjoyed', 1468),
#  ('hilarious', 1468),
#  ('musical', 1468),
#  ('cop', 1468),
#  ('message', 1464),
#  ('happy', 1464),
#  ('pay', 1464),
#  ('box', 1460),
#  ('laughs', 1460),
#  ('suspense', 1452),
#  ('sadly', 1452),
#  ('eye', 1448),
#  ('similar', 1444),
#  ('third', 1444),
#  ('named', 1444),
#  ('modern', 1440),
#  ('events', 1436),
#  ('failed', 1436),
#  ('forget', 1432),
#  ('question', 1432),
#  ('male', 1428),
#  ('finds', 1428),
#  ('perfect', 1424),
#  ('sister', 1420),
#  ('spent', 1420),
#  ('feature', 1416),
#  ('result', 1416),
#  ('girlfriend', 1412),
#  ('comment', 1412),
#  ('sexual', 1408),
#  ('attempts', 1404),
#  ('neither', 1404),
#  ('richard', 1404),
#  ('screenplay', 1400),
#  ('elements', 1400),
#  ('spoilers', 1396),
#  ('brain', 1392),
#  ('filmmakers', 1392),
#  ('showing', 1392),
#  ('dr', 1388),
#  ('christmas', 1388),
#  ('miss', 1388),
#  ('cover', 1380),
#  ('sequences', 1376),
#  ('red', 1376),
#  ('excuse', 1372),
#  ('typical', 1372),
#  ('ideas', 1368),
#  ('crazy', 1368),
#  ('baby', 1368),
#  ('loved', 1364),
#  ('meant', 1364),
#  ('worked', 1360),
#  ('fire', 1360),
#  ('unbelievable', 1356),
#  ('follow', 1356),
#  ('theme', 1348),
#  ('plus', 1344),
#  ('producers', 1344),
#  ('twist', 1344),
#  ('appear', 1344),
#  ('barely', 1344),
#  ('team', 1340),
#  ('directors', 1340),
#  ('viewers', 1332),
#  ('leads', 1328),
#  ('slasher', 1328),
#  ('tom', 1328),
#  ('wrote', 1324),
#  ('working', 1324),
#  ('gun', 1324),
#  ('villain', 1324),
#  ('strong', 1320),
#  ('island', 1320),
#  ('realize', 1320),
#  ('open', 1320),
#  ('yeah', 1316),
#  ('quickly', 1316),
#  ('disappointing', 1316),
#  ('positive', 1316),
#  ('simple', 1312),
#  ('weren', 1312),
#  ('release', 1312),
#  ('honestly', 1312),
#  ('doctor', 1308),
#  ('tells', 1308),
#  ('period', 1308),
#  ('eventually', 1308),
#  ('kills', 1308),
#  ('acted', 1304),
#  ('herself', 1304),
#  ('list', 1304),
#  ('nowhere', 1304),
#  ('dog', 1304),
#  ('walk', 1300),
#  ('air', 1296),
#  ('apart', 1296),
#  ('subject', 1292),
#  ('makers', 1292),
#  ('learn', 1288),
#  ('fi', 1288),
#  ('bother', 1276),
#  ('admit', 1276),
#  ('sci', 1276),
#  ('note', 1272),
#  ('jack', 1272),
#  ('disappointment', 1272),
#  ('hands', 1272),
#  ('e', 1268),
#  ('certain', 1268),
#  ('value', 1268),
#  ('casting', 1268),
#  ('peter', 1264),
#  ('grade', 1264),
#  ('missing', 1260),
#  ('suddenly', 1260),
#  ('stick', 1252),
#  ('previous', 1252),
#  ('break', 1252),
#  ('form', 1252),
#  ('soundtrack', 1248),
#  ('surprised', 1244),
#  ('expecting', 1244),
#  ('front', 1244),
#  ('parents', 1240),
#  ('relationship', 1240),
#  ('surprise', 1240),
#  ('shoot', 1236),
#  ('today', 1236),
#  ('painful', 1232),
#  ('concept', 1232),
#  ('creepy', 1232),
#  ('leaves', 1232),
#  ('ways', 1232),
#  ('ended', 1232),
#  ('vampire', 1232),
#  ('somewhere', 1232),
#  ('spend', 1228),
#  ('th', 1228),
#  ('street', 1224),
#  ('effect', 1224),
#  ('future', 1224),
#  ('fighting', 1224),
#  ('difficult', 1224),
#  ('c', 1220),
#  ('america', 1220),
#  ('accent', 1216),
#  ('project', 1208),
#  ('truth', 1208),
#  ('deal', 1204),
#  ('indeed', 1204),
#  ('joe', 1204),
#  ('f', 1204),
#  ('biggest', 1200),
#  ('rate', 1200),
#  ('paul', 1196),
#  ('japanese', 1196),
#  ('college', 1192),
#  ('redeeming', 1192),
#  ('begins', 1192),
#  ('utterly', 1192),
#  ('york', 1188),
#  ('disney', 1188),
#  ('fairly', 1188),
#  ('create', 1184),
#  ('cartoon', 1184),
#  ('revenge', 1184),
#  ('crew', 1184),
#  ('outside', 1180),
#  ('computer', 1180),
#  ('interested', 1180),
#  ('stage', 1180),
#  ('co', 1180),
#  ('speak', 1176),
#  ('considering', 1176),
#  ('among', 1176),
#  ('sick', 1172),
#  ('channel', 1172),
#  ('towards', 1172),
#  ('van', 1168),
#  ('particular', 1168),
#  ('cause', 1168),
#  ('talented', 1168),
#  ('hair', 1168),
#  ('bottom', 1164),
#  ('reasons', 1164),
#  ('telling', 1160),
#  ('cat', 1160),
#  ('mediocre', 1160),
#  ('store', 1156),
#  ('supporting', 1156),
#  ('waiting', 1152),
#  ('hoping', 1152),
#  ('became', 1148),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
#       Consider words to be "common" if they've been used at least 100 times
for word in list(total_counts):
    if total_counts[word] >= 100:
        pos_neg_ratios[word] = positive_counts[word] / float(negative_counts[word]+1)

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.2652010459684465
# Pos-to-neg ratio for 'amazing' = 1.0085795996186844
# Pos-to-neg ratio for 'terrible' = 0.044384546271338726

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
# TODO: Convert ratios to logs
for word in list(pos_neg_ratios):
    pos_neg_ratios[word] = np.log(pos_neg_ratios[word]+.5)

# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = -0.26761667449532356
# Pos-to-neg ratio for 'amazing' = 0.41116854562203403
# Pos-to-neg ratio for 'terrible' = -0.6080993953246016

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 4.6959245492565556),
#  ('antwone', 4.4830025520138834),
#  ('din', 4.4127982933406349),
#  ('gunga', 4.1972019476618083),
#  ('goldsworthy', 4.1820501426412067),
#  ('gypo', 4.1026433650367959),
#  ('yokai', 4.1026433650367959),
#  ('visconti', 3.9415818076696905),
#  ('flavia', 3.9415818076696905),
#  ('kells', 3.8815637979434374),
#  ('blandings', 3.8815637979434374),
#  ('brashear', 3.8607297110405954),
#  ('gino', 3.8394523125933104),
#  ('deathtrap', 3.8177123259569048),
#  ('panahi', 3.7256934272366524),
#  ('harilal', 3.7256934272366524),
#  ('ossessione', 3.6763006719070761),
#  ('caruso', 3.6506582412937387),
#  ('tsui', 3.6506582412937387),
#  ('ahmad', 3.6243409329763652),
#  ('sabu', 3.6243409329763652),
#  ('dominick', 3.597312260588446),
#  ('khouri', 3.597312260588446),
#  ('aweigh', 3.5695326964813701),
#  ('mj', 3.5695326964813701),
#  ('kriemhild', 3.5409593240373143),
#  ('mcintire', 3.5409593240373143),
#  ('daisies', 3.5115454388310208),
#  ('newcombe', 3.5115454388310208),
#  ('blackie', 3.5115454388310208),
#  ('trelkovsky', 3.4812400893356918),
#  ('kei', 3.4812400893356918),
#  ('jaffar', 3.4499875458315872),
#  ('hilliard', 3.4499875458315872),
#  ('pazu', 3.417726683613366),
#  ('sheeta', 3.417726683613366),
#  ('offside', 3.417726683613366),
#  ('bathsheba', 3.417726683613366),
#  ('krell', 3.417726683613366),
#  ('fineman', 3.3843902633457743),
#  ('venoms', 3.3843902633457743),
#  ('paine', 3.3499040872746049),
#  ('ranma', 3.3499040872746049),
#  ('pimlico', 3.3499040872746049),
#  ('ronny', 3.3499040872746049),
#  ('abhay', 3.3141860046725258),
#  ('pym', 3.2771447329921766),
#  ('kipling', 3.2771447329921766),
#  ('audiard', 3.2386784521643803),
#  ('milverton', 3.2386784521643803),
#  ('scalise', 3.2386784521643803),
#  ('kelso', 3.2386784521643803),
#  ('gabe', 3.2386784521643803),
#  ('paulie', 3.1822118404966093),
#  ('iturbi', 2.4069451083182885),
#  ('gundam', 2.3723184310087206),
#  ('giovanna', 2.3125354238472138),
#  ('feinstone', 2.3125354238472138),
#  ('luzhin', 2.2512917986064953),
#  ('philo', 2.2082744135228043),
#  ('lindy', 2.1860512767380942),
#  ('clutter', 2.1162555148025524),
#  ('anchors', 2.0918640616783932),
#  ('korda', 2.0149030205422647),
#  ('felix', 1.9990924145156226),
#  ('callahan', 1.9878743481543455),
#  ('capote', 1.9848255653049869),
#  ('aiello', 1.9600947840472698),
#  ('excellently', 1.9538153285624265),
#  ('fido', 1.9066894359020321),
#  ('hayworth', 1.9054187877005764),
#  ('deanna', 1.9054187877005764),
#  ('bake', 1.9021075263969205),
#  ('ashraf', 1.8718021769015913),
#  ('aviv', 1.8718021769015913),
#  ('hickock', 1.8718021769015913),
#  ('eustache', 1.8718021769015913),
#  ('vance', 1.8478489358790986),
#  ('beery', 1.8405496333974869),
#  ('conroy', 1.8405496333974869),
#  ('dench', 1.8405496333974869),
#  ('partition', 1.8405496333974869),
#  ('sammo', 1.8370160608161759),
#  ('kolchak', 1.8356536627852802),
#  ('laputa', 1.8191584434161694),
#  ('pang', 1.8082887711792655),
#  ('dev', 1.7749523509116738),
#  ('fricker', 1.7749523509116738),
#  ('katsu', 1.7749523509116738),
#  ('emil', 1.7749523509116738),
#  ('sox', 1.7458497679239771),
#  ('myrtle', 1.7443572303334711),
#  ('gackt', 1.7443572303334711),
#  ('adele', 1.7443572303334711),
#  ('saura', 1.7404661748405046),
#  ('alvin', 1.7323360487572543),
#  ('gannon', 1.7047480922384253),
#  ('biko', 1.7047480922384253),
#  ('bernsen', 1.7047480922384253),
#  ('mathieu', 1.6906633523566863),
#  ('polanski', 1.6695021531767504),
#  ('blackadder', 1.6677068205580761),
#  ('unpretentious', 1.6677068205580761),
#  ('lupino', 1.6677068205580761),
#  ('perdition', 1.6677068205580761),
#  ('binder', 1.6677068205580761),
#  ('yuzna', 1.6677068205580761),
#  ('gilliam', 1.6471782404169475),
#  ('matthau', 1.6124636333506375),
#  ('harriet', 1.5702171992808189),
#  ('chavez', 1.5550438403683016),
#  ('zu', 1.5522794985941517),
#  ('warhols', 1.5522794985941517),
#  ('sammi', 1.5522794985941517),
#  ('abu', 1.5522794985941517),
#  ('ratso', 1.5425436776040702),
#  ('ultimatum', 1.5376940075752592),
#  ('rosenstrasse', 1.5284688499004331),
#  ('taker', 1.479076094570857),
#  ('delightfully', 1.4692912806908587),
#  ('victoria', 1.4683593141741949),
#  ('durbin', 1.4534336639575192),
#  ('creasy', 1.451433663290852),
#  ('corbett', 1.4503732178044131),
#  ('mildred', 1.4408151999983074),
#  ('mclaglen', 1.4384801142904609),
#  ('vonnegut', 1.4147322964404241),
#  ('braveheart', 1.4081134085145304),
#  ('pita', 1.4000876832522264),
#  ('natali', 1.3958638121360414),
#  ('kazan', 1.3936204012119635),
#  ('sirk', 1.3812818192963463),
#  ('gandhi', 1.3748656652962679),
#  ('mccoy', 1.3437347467010947),
#  ('tigerland', 1.3437347467010947),
#  ('flamenco', 1.3437347467010947),
#  ('cheadle', 1.3334518797455106),
#  ('othello', 1.3190856114264407),
#  ('elsa', 1.3166144404819009),
#  ('sullavan', 1.3143208614948014),
#  ('olympia', 1.3143208614948014),
#  ('aunts', 1.3143208614948014),
#  ('novak', 1.3083328196501789),
#  ('jabba', 1.2957803535790589),
#  ('flawless', 1.2906462863976693),
#  ('cal', 1.2858238307562562),
#  ('tomlinson', 1.2840155119994725),
#  ('christy', 1.2818912414183916),
#  ('fuller', 1.275362800412609),
#  ('ramones', 1.275362800412609),
#  ('coop', 1.2745029551317739),
#  ('magnificently', 1.2527629684953681),
#  ('fagin', 1.2527629684953681),
#  ('complement', 1.2527629684953681),
#  ('benet', 1.2527629684953681),
#  ('raoul', 1.2527629684953681),
#  ('hanzo', 1.2527629684953681),
#  ('winchester', 1.2390641241372062),
#  ('haines', 1.2358134101815947),
#  ('rea', 1.2358134101815947),
#  ('colman', 1.2358134101815947),
#  ('beetle', 1.2305398317106577),
#  ('chamberlain', 1.225175011976539),
#  ('weir', 1.2205021062771466),
#  ('marvelously', 1.2205021062771466),
#  ('iris', 1.2205021062771466),
#  ('influential', 1.2078115806331018),
#  ('kalifornia', 1.2078115806331018),
#  ('wodehouse', 1.1871656860095547),
#  ('vertigo', 1.1845547184688343),
#  ('northam', 1.1831696766961728),
#  ('stardust', 1.1649873576129823),
#  ('stevenson', 1.1607440697751159),
#  ('finely', 1.1607440697751159),
#  ('cheung', 1.1607440697751159),
#  ('carla', 1.1599128145319055),
#  ('fez', 1.1526795099383853),
#  ('abbot', 1.1526795099383853),
#  ('iago', 1.1526795099383853),
#  ('romy', 1.1526795099383853),
#  ('devos', 1.1526795099383853),
#  ('footlight', 1.1526795099383853),
#  ('sabrina', 1.1490431422950016),
#  ('peters', 1.1380540207194063),
#  ('kinnear', 1.1375277049177832),
#  ('celine', 1.1363526166509568),
#  ('tenant', 1.1314021114911006),
#  ('tintin', 1.1169614273363062),
#  ('superbly', 1.1169614273363062),
#  ('curtiz', 1.1169614273363062),
#  ('duchess', 1.1169614273363062),
#  ('quotable', 1.1169614273363062),
#  ('vulnerability', 1.1113513144455394),
#  ('marjorie', 1.1113513144455394),
#  ('darius', 1.1113513144455394),
#  ('hark', 1.1113513144455394),
#  ('enchanting', 1.1083684636134743),
#  ('raines', 1.0928485839513595),
#  ('pecker', 1.0887599922250981),
#  ('duryea', 1.0857088838322018),
#  ('benoit', 1.0857088838322018),
#  ('georges', 1.0784095813505903),
#  ('devotion', 1.0687593255184284),
#  ('tel', 1.0593915755148284),
#  ('askey', 1.0593915755148284),
#  ('ella', 1.0593915755148284),
#  ('fairytale', 1.0593915755148284),
#  ('rukh', 1.052092273033217),
#  ('trier', 1.0508216248317612),
#  ('blaine', 1.032362903126909),
#  ('dixon', 1.0286537000611993),
#  ('cheech', 1.0275163669843794),
#  ('perfection', 1.0227033254827851),
#  ('miyazaki', 1.0198314108149955),
#  ('astaire', 1.0098841730594255),
#  ('venezuela', 1.0045833390198333),
#  ('edith', 0.98971820042897229),
#  ('malone', 0.98649499054740353),
#  ('clarence', 0.98449898190068863),
#  ('transcends', 0.97600996657577732),
#  ('singin', 0.97600996657577732),
#  ('wtc', 0.97600996657577732),
#  ('rathbone', 0.97600996657577732),
#  ('mol', 0.96999491084601608),
#  ('pickford', 0.95683682626850497),
#  ('scoop', 0.95683682626850497),
#  ('zorro', 0.94778939893352609),
#  ('adelaide', 0.94659608136948403),
#  ('lighten', 0.94659608136948403),
#  ('turturro', 0.94659608136948403),
#  ('mostel', 0.93954759403842225),
#  ('enthralling', 0.93954759403842225),
#  ('henderson', 0.93954759403842225),
#  ('dandy', 0.92998957623231693),
#  ('voight', 0.92442085795740525),
#  ('superlative', 0.91629073187415511),
#  ('heartbreaking', 0.91629073187415511),
#  ('labyrinth', 0.91629073187415511),
#  ('lila', 0.91629073187415511),
#  ('eagle', 0.59351733961110398),
#  ('layered', 0.59351733961110398),
#  ('scarlett', 0.59351733961110398),
#  ('hartley', 0.59205106368857652),
#  ('unforgettable', 0.58838385811186511),
#  ('touching', 0.58719336912678033),
#  ('trey', 0.5845133395571499),
#  ('akira', 0.5845133395571499),
#  ('humane', 0.5845133395571499),
#  ('fateful', 0.5845133395571499),
#  ('mesmerizing', 0.58371333951448323),
#  ('favorites', 0.58180000184580338),
#  ('mischievous', 0.57981849525294216),
#  ('poppins', 0.57981849525294216),
#  ('realist', 0.57981849525294216),
#  ('sweetheart', 0.57981849525294216),
#  ('nielsen', 0.57981849525294216),
#  ('albums', 0.57981849525294216),
#  ('planets', 0.57981849525294216),
#  ('extraordinary', 0.57840156267439713),
#  ('shanghai', 0.57830792094757522),
#  ('maturity', 0.57661336430399379),
#  ('sullivan', 0.57661336430399379),
#  ('gently', 0.57661336430399379),
#  ('conflicted', 0.57661336430399379),
#  ('showcases', 0.57661336430399379),
#  ('iran', 0.57587630880720309),
#  ('captivated', 0.57428597768321654),
#  ('fritz', 0.57428597768321654),
#  ('relaxed', 0.57428597768321654),
#  ('johansson', 0.57251919277133057),
#  ('delirious', 0.57251919277133057),
#  ('fairbanks', 0.57113222999698177),
#  ('wrenching', 0.5700144951563213),
#  ('heartwarming', 0.56909453188996639),
#  ('stewart', 0.56836152837538001),
#  ('brilliantly', 0.56220982311246936),
#  ('watson', 0.55710637632999704),
#  ('election', 0.55643613501804301),
#  ('lang', 0.55574731115750231),
#  ('rowlands', 0.55574731115750231),
#  ('gretchen', 0.55467750629484014),
#  ('blondell', 0.55467750629484014),
#  ('crowe', 0.55467750629484014),
#  ('dictator', 0.55467750629484014),
#  ('cloth', 0.55388511322643763),
#  ('irs', 0.55278982286502287),
#  ('sherry', 0.55278982286502287),
#  ('gertrude', 0.55278982286502287),
#  ('postman', 0.55278982286502287),
#  ('celie', 0.55278982286502287),
#  ('coen', 0.55278982286502287),
#  ('blends', 0.55278982286502287),
#  ('illinois', 0.55117691928955814),
#  ('wickedly', 0.55117691928955814),
#  ('adversity', 0.55117691928955814),
#  ('denholm', 0.55117691928955814),
#  ('tragedies', 0.55117691928955814),
#  ('evolves', 0.55117691928955814),
#  ('affluent', 0.55117691928955814),
#  ('outlaws', 0.55117691928955814),
#  ('palma', 0.54978286701918377),
#  ('understated', 0.54783708874281001),
#  ('simmons', 0.54700528034349305),
#  ('friendship', 0.54093762072103169),
#  ('elliott', 0.54012199325442156),
#  ('shahid', 0.53773307668591508),
#  ('cena', 0.53773307668591508),
#  ('benefits', 0.53773307668591508),
#  ('diego', 0.53773307668591508),
#  ('ritter', 0.53315510016407941),
#  ('conveys', 0.53302633374618325),
#  ('metropolis', 0.53062825106217038),
#  ('climate', 0.53062825106217038),
#  ('maguire', 0.53062825106217038),
#  ('wonderful', 0.529600237607462),
#  ('loy', 0.52775468586643859),
#  ('magnificent', 0.52672072411044035),
#  ('nathan', 0.52649174051039005),
#  ('smooth', 0.24373018492259815),
#  ('playwright', 0.24334625863172918),
#  ('simplicity', 0.24316646718931745),
#  ('shelley', 0.24231346742192991),
#  ('sensitive', 0.24217042636890379),
#  ('dramas', 0.24194381581435706),
#  ('owl', 0.24183568432636235),
#  ('arkin', 0.24183568432636235),
#  ('isolation', 0.2405352940260789),
#  ('packs', 0.2405352940260789),
#  ('contribution', 0.23940407218599002),
#  ('dazzling', 0.23940407218599002),
#  ('beatles', 0.23674920336998834),
#  ('vader', 0.23674920336998834),
#  ('inspiring', 0.23658662157066254),
#  ('wwe', 0.23604695615011775),
#  ('deniro', 0.23541364390602398),
#  ('warmth', 0.23483959107740099),
#  ('tends', 0.23483959107740099),
#  ('june', 0.23431685191233506),
#  ('thoughtful', 0.23340005148139881),
#  ('stellar', 0.2329958477572214),
#  ('brothel', 0.23111172096338664),
#  ('parole', 0.23111172096338664),
#  ('breeze', 0.23111172096338664),
#  ('calamity', 0.23111172096338664),
#  ('contemporaries', 0.23111172096338664),
#  ('suburbia', 0.23111172096338664),
#  ('beginnings', 0.23111172096338664),
#  ('gameplay', 0.23111172096338664),
#  ('helps', 0.23040007213203587),
#  ('expressive', 0.23001643060197177),
#  ('familiarity', 0.23001643060197177),
#  ('depalma', 0.23001643060197177),
#  ('brash', 0.23001643060197177),
#  ('rests', 0.22918586577017239),
#  ('lombard', 0.22918586577017239),
#  ('sentenced', 0.22918586577017239),
#  ('strikingly', 0.22918586577017239),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = set(total_counts)

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74073

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros((1,vocab_size))

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74073)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'wonk': 0,
#  'impenetrable': 1,
#  'chocula': 24693,
#  'intergenerational': 2,
#  'yolonda': 18092,
#  'tts': 24694,
#  'aid': 5,
#  'sandwich': 4,
#  'hurricanes': 6,
#  'znaimer': 12357,
#  'rsc': 7,
#  'loooong': 8,
#  'zurich': 49391,
#  'silverstonesque': 9,
#  'leesville': 10,
#  'sheryl': 24698,
#  'newsome': 41947,
#  'nechayev': 12,
#  'comedic': 60331,
#  'deadlier': 66577,
#  'mindel': 22,
#  'mlis': 16,
#  'homophobia': 18,
#  'martians': 20,
#  'involvements': 21,
#  'zoned': 49826,
#  'reicher': 23,
#  'fullmoon': 24,
#  'regal': 25,
#  'furtilized': 26,
#  'levitt': 28,
#  'downmarket': 29,
#  'mucci': 30,
#  'haige': 31,
#  'deployed': 49395,
#  'components': 32,
#  'waterman': 34,
#  'spilt': 36,
#  'overhauled': 37,
#  'mariya': 38,
#  'velveeta': 39,
#  'denies': 40,
#  'reconsiders': 41,
#  'complacent': 43,
#  'changs': 44,
#  'archibald': 45,
#  'yeller': 49402,
#  'shared': 47,
#  'devin': 48,
#  'physicist': 50,
#  'putdowns': 52,
#  'righteousness': 53,
#  'knocking': 54,
#  'ingnue': 56,
#  'beaty': 58,
#  'leered': 59,
#  'nostras': 60,
#  'invincibility': 61,
#  'stabbings': 62,
#  'negotiating': 63,
#  'flapping': 5852,
#  'slouch': 64,
#  'inom': 65,
#  'find': 55985,
#  'pingo': 70,
#  'urgh': 71,
#  'kronfeld': 74,
#  'cramped': 73,
#  'mish': 75,
#  'roofthooft': 76,
#  'voyeuristic': 79,
#  'apologetically': 78,
#  'michaelangelo': 80,
#  'dewitt': 81,
#  'apparatus': 14547,
#  'tortu': 83,
#  'viju': 84,
#  'warnings': 86,
#  'paradorian': 49408,
#  'confounded': 36910,
#  'carfare': 87,
#  'sighting': 88,
#  'forestry': 61699,
#  'fellas': 89,
#  'ntr': 90,
#  'fakeness': 91,
#  'latinamerica': 92,
#  'safely': 36912,
#  'aaja': 93,
#  'greytack': 24711,
#  'disruptive': 94,
#  'heather': 96,
#  'karvan': 97,
#  'bhagat': 103,
#  'neurosis': 101,
#  'coroner': 100,
#  'sketchlike': 105,
#  'huppertz': 102,
#  'boulting': 104,
#  'cockfighting': 106,
#  'hs': 18153,
#  'franks': 108,
#  'homepages': 110,
#  'overblown': 111,
#  'subatomic': 112,
#  'canfield': 113,
#  'catholiques': 58623,
#  'lumpur': 115,
#  'pianist': 116,
#  'toppling': 126,
#  'marina': 118,
#  'current': 119,
#  'ntsb': 121,
#  'ittami': 122,
#  'depravity': 123,
#  'credible': 124,
#  'boxing': 125,
#  'legion': 13,
#  'poisen': 127,
#  'bejesus': 131,
#  'lifewell': 130,
#  'shakewspeare': 36918,
#  'gellar': 133,
#  'strangulation': 134,
#  'nekoski': 135,
#  'paduch': 17,
#  'cappra': 136,
#  'blessing': 61704,
#  'fuzzy': 51612,
#  'roseanna': 51710,
#  'akki': 137,
#  'imagining': 138,
#  'paedophile': 19,
#  'audiance': 61707,
#  'izetbegovic': 139,
#  'carves': 140,
#  'chronologies': 141,
#  'visibile': 61710,
#  'rheostatics': 142,
#  'choreographing': 24716,
#  'decorative': 143,
#  'surge': 144,
#  'mar': 36922,
#  'blatant': 24719,
#  'shounen': 148,
#  'gotterdammerung': 146,
#  'sacrilege': 147,
#  'epitaphs': 14662,
#  'iodine': 149,
#  'bounding': 4777,
#  'stockholm': 150,
#  'sperms': 151,
#  'demons': 153,
#  'ow': 154,
#  'anticlimax': 155,
#  'apalled': 156,
#  'nunnery': 157,
#  'albatross': 24722,
#  'faghag': 158,
#  'panavision': 12379,
#  'colassanti': 159,
#  'codes': 27,
#  'pronouncements': 160,
#  'prashant': 161,
#  'sanitize': 163,
#  'tobei': 164,
#  'gustav': 24724,
#  'exclusives': 165,
#  'extraterrestrial': 166,
#  'kirkin': 167,
#  'janowski': 168,
#  'britspeak': 169,
#  'beams': 170,
#  'condorwhich': 172,
#  'zhang': 12383,
#  'inexpertly': 173,
#  'punters': 174,
#  'speak': 177,
#  'hijacker': 178,
#  'mastercard': 179,
#  'vexing': 61717,
#  'fantastico': 180,
#  'battlefields': 181,
#  'weekends': 49420,
#  'quipped': 182,
#  'roehler': 183,
#  'hybridnot': 184,
#  'aranoa': 36929,
#  'antigen': 185,
#  'judas': 186,
#  'anesthesiologists': 188,
#  'shakespere': 24732,
#  'godmother': 189,
#  'disasterpiece': 190,
#  'endanger': 193,
#  'genial': 192,
#  'ashes': 194,
#  'provocation': 30007,
#  'n': 196,
#  'rejects': 197,
#  'nacht': 198,
#  'overbroad': 25225,
#  'sanam': 202,
#  'humanitarians': 200,
#  'preference': 201,
#  'kinkle': 35,
#  'outnumbers': 203,
#  'charred': 204,
#  'pfifer': 205,
#  'bleary': 206,
#  'recieve': 207,
#  'freuchen': 208,
#  'martinets': 209,
#  'concisely': 210,
#  'baptized': 211,
#  'hud': 212,
#  'waif': 213,
#  'ripoff': 24740,
#  'unfortuanitly': 68080,
#  'clubberin': 216,
#  'mizu': 215,
#  'resignedly': 24739,
#  'occhi': 217,
#  'stupefyingly': 218,
#  'boyhood': 219,
#  'sufice': 221,
#  'massacessi': 49430,
#  'infesting': 224,
#  'filthy': 223,
#  'gestures': 24741,
#  'implication': 225,
#  'learnt': 226,
#  'gallipolli': 228,
#  'acus': 229,
#  'ahista': 230,
#  'backed': 233,
#  'yrds': 234,
#  'fishnet': 4663,
#  'stassard': 235,
#  'catchphrases': 236,
#  'watership': 36937,
#  'served': 237,
#  'whiner': 238,
#  'mt': 240,
#  'canals': 241,
#  'initiation': 243,
#  'rosarios': 244,
#  'bogarde': 245,
#  'morcheeba': 246,
#  'facility': 31735,
#  'sense': 248,
#  'xtreme': 18032,
#  'dangly': 249,
#  'huggy': 250,
#  'greaser': 252,
#  'zombs': 253,
#  'puleeze': 254,
#  'lajos': 255,
#  'boffin': 49438,
#  'superannuated': 42,
#  'viper': 256,
#  'baltron': 258,
#  'bugliosa': 260,
#  'manikins': 262,
#  'motley': 46,
#  'pidgin': 263,
#  'squirtguns': 264,
#  'andrei': 265,
#  'leit': 268,
#  'adopting': 267,
#  'besson': 269,
#  'hershman': 51,
#  'thuggish': 274,
#  'lunchrooms': 35533,
#  'farenheight': 61737,
#  'manny': 275,
#  'ludlum': 49442,
#  'zilch': 276,
#  'soles': 49,
#  'teapot': 277,
#  'worrying': 36949,
#  'wearers': 278,
#  'compadre': 280,
#  'murray': 12403,
#  'disgustingly': 281,
#  'myia': 284,
#  'seberg': 283,
#  'thurman': 285,
#  'mourn': 286,
#  'eko': 287,
#  'mvt': 288,
#  'collaborated': 289,
#  'dockside': 291,
#  'videocassette': 292,
#  'idolized': 34272,
#  'hunky': 52444,
#  'warrick': 294,
#  'practically': 295,
#  'catalog': 298,
#  'megalomania': 297,
#  'perspectives': 73560,
#  'floppy': 58328,
#  'lascivious': 299,
#  'zarustica': 24749,
#  'ibiza': 300,
#  'gelled': 301,
#  'upham': 302,
#  'russwill': 303,
#  'tongued': 64276,
#  'unfunny': 304,
#  'kosmos': 305,
#  'erics': 307,
#  'uni': 308,
#  'espouse': 309,
#  'airball': 310,
#  'bufoonery': 311,
#  'chattel': 55,
#  'riksihi': 312,
#  'going': 313,
#  'pendant': 314,
#  'mystique': 57,
#  'firmware': 315,
#  'humbleness': 57217,
#  'scouting': 316,
#  'krebs': 61744,
#  'boland': 317,
#  'bakersfeild': 318,
#  'flashbacked': 320,
#  'charactershe': 322,
#  'bartley': 69787,
#  'neglects': 323,
#  'watchmen': 29664,
#  'jouanneau': 324,
#  'stresses': 12409,
#  'lelia': 325,
#  'palmer': 326,
#  'embry': 71062,
#  'jessie': 327,
#  'admittance': 328,
#  'revolutionairies': 329,
#  'megs': 31210,
#  'ramtha': 330,
#  'jon': 331,
#  'snaps': 61746,
#  'eastland': 333,
#  'coates': 334,
#  'apollo': 335,
#  'warbling': 336,
#  'leonel': 49452,
#  'ploys': 339,
#  'cohabiting': 66,
#  'digression': 341,
#  'guidelines': 345,
#  'dedicate': 67,
#  'newspeople': 346,
#  'broadened': 347,
#  'prey': 348,
#  'riffling': 349,
#  'fossil': 353,
#  'marnack': 351,
#  'laughably': 24762,
#  'thorstein': 69857,
#  'awsome': 354,
#  'eventide': 355,
#  'sledding': 356,
#  'sociology': 59861,
#  'border': 358,
#  'starry': 359,
#  'improvise': 360,
#  'ahmed': 363,
#  'uneasily': 364,
#  'wopr': 365,
#  'reisman': 366,
#  'dilatory': 370,
#  'petulantly': 371,
#  'primally': 372,
#  'gravitate': 373,
#  'rap': 374,
#  'brought': 49457,
#  'churchman': 375,
#  'without': 376,
#  'storyboarded': 377,
#  'happyend': 61754,
#  'huntsman': 378,
#  'maritime': 381,
#  'likeminded': 380,
#  'housemates': 24767,
#  'insights': 382,
#  'tomiche': 384,
#  'bauman': 385,
#  'reconciled': 386,
#  'cloris': 63421,
#  'fostering': 55988,
#  'infallible': 69,
#  'wretched': 388,
#  'grusiya': 61757,
#  'bhandarkar': 49461,
#  'smartness': 389,
#  'seguin': 390,
#  'arenas': 391,
#  'housed': 40723,
#  'pulsates': 393,
#  'ninjo': 394,
#  'endeavour': 72,
#  'holies': 395,
#  'eleven': 396,
#  'backstage': 398,
#  'sleepover': 36970,
#  'dusters': 400,
#  'vedma': 401,
#  'macmurphy': 24772,
#  'abdomen': 12422,
#  'hidden': 402,
#  'dissolving': 403,
#  'capping': 16502,
#  'insted': 404,
#  'hammering': 405,
#  'intruding': 406,
#  'offputting': 409,
#  'scavenging': 408,
#  'bak': 410,
#  'conflagration': 412,
#  'counterbalanced': 413,
#  'hanneke': 61760,
#  'improv': 417,
#  'currie': 24775,
#  'proplems': 419,
#  'puuurfect': 29137,
#  'sopranos': 420,
#  'cringingly': 24776,
#  'leoncavallo': 423,
#  'turret': 422,
#  'simonson': 47523,
#  'novotna': 61763,
#  'gurantee': 20801,
#  'camp': 67234,
#  'bodies': 424,
#  'defiance': 425,
#  'tara': 428,
#  'overstuffed': 427,
#  'hinge': 431,
#  'disbarred': 430,
#  'ornithologist': 433,
#  'netlaska': 434,
#  'poelzig': 435,
#  'melato': 85,
#  'dolby': 70903,
#  'biceps': 49471,
#  'amiable': 436,
#  'ozjeppe': 68842,
#  'tenable': 57025,
#  'earhart': 437,
#  'wowing': 438,
#  'molina': 29126,
#  'sift': 439,
#  'sunjata': 441,
#  'competitor': 442,
#  'bigotry': 443,
#  'threatens': 444,
#  'fairhaired': 445,
#  'slope': 446,
#  'mangeshkar': 447,
#  'informercial': 448,
#  'bravery': 449,
#  'nimoy': 61770,
#  'sylvain': 451,
#  'gramma': 452,
#  'degree': 36983,
#  'soderbergh': 453,
#  'paternally': 454,
#  'sublime': 455,
#  'frighteners': 456,
#  'escapism': 457,
#  'dorky': 458,
#  'dower': 461,
#  'indecisively': 460,
#  'straightens': 464,
#  'compromising': 63017,
#  'severely': 465,
#  'smalltown': 468,
#  'spiderwoman': 469,
#  'nite': 42587,
#  'vcrs': 66006,
#  'pistoning': 471,
#  'examplepeter': 473,
#  'potenta': 474,
#  'workandthere': 72679,
#  'lela': 63370,
#  'coach': 475,
#  'navet': 476,
#  'creely': 12440,
#  'maude': 477,
#  'genghis': 478,
#  'braincells': 53662,
#  'fondue': 479,
#  'discustingly': 480,
#  'symbolize': 56628,
#  'elan': 482,
#  'graziano': 483,
#  'cathedral': 484,
#  'votes': 485,
#  'assent': 68743,
#  'prematurelyleaving': 61775,
#  'seasick': 486,
#  'disservice': 36992,
#  'tangents': 487,
#  'stefano': 73321,
#  'stewardship': 488,
#  'doctorine': 489,
#  'unwittingly': 491,
#  'donnacha': 68558,
#  'galileo': 492,
#  'jegede': 493,
#  'tingles': 49485,
#  'innappropriate': 5485,
#  'allocation': 494,
#  'dysfuntional': 495,
#  'alongs': 496,
#  'gag': 498,
#  'carmilla': 499,
#  'headed': 501,
#  'rhys': 52523,
#  'shoeless': 506,
#  'reconstruct': 507,
#  'numeric': 508,
#  'amitabhs': 510,
#  'carroll': 511,
#  'hamari': 512,
#  'schwarzenegger': 514,
#  'apes': 515,
#  'eally': 58544,
#  'wienstein': 516,
#  'aladdin': 12445,
#  'bronchitis': 21184,
#  'paluzzi': 517,
#  'reanimated': 518,
#  'unaffected': 519,
#  'ladki': 95,
#  'waystation': 526,
#  'automata': 523,
#  'whiplash': 524,
#  'handguns': 525,
#  'rascally': 24791,
#  'ballets': 527,
#  'thrived': 28357,
#  'batting': 529,
#  'connaught': 530,
#  'whacked': 531,
#  'incorporation': 532,
#  'tombstone': 23203,
#  'differences': 534,
#  'papers': 535,
#  'lobotomy': 539,
#  'frikkin': 540,
#  'kabob': 541,
#  'venereal': 542,
#  'pivots': 543,
#  'jymn': 544,
#  'discotheque': 9981,
#  'facto': 57393,
#  'classic': 545,
#  'untwining': 61784,
#  'patti': 546,
#  'bedraggled': 548,
#  'recasting': 99,
#  'uh': 549,
#  'cloistered': 550,
#  'fyall': 552,
#  'shushui': 553,
#  'definitive': 65381,
#  'lie': 554,
#  'fkin': 555,
#  'tail': 556,
#  'pseudoscientist': 557,
#  'littleoff': 558,
#  'disappointingit': 559,
#  'portraited': 560,
#  'erode': 561,
#  'whey': 562,
#  'magruder': 66870,
#  'dighton': 563,
#  'gadget': 564,
#  'meagan': 566,
#  'interpretations': 67585,
#  'beavis': 72183,
#  'entrenched': 567,
#  'libertini': 24798,
#  'frazee': 54190,
#  'sundays': 568,
#  'bodyguard': 569,
#  'piling': 16801,
#  'crach': 570,
#  'morph': 571,
#  'pollak': 572,
#  'litel': 574,
#  'goldustluna': 576,
#  'gnome': 577,
#  'izo': 49496,
#  'hein': 578,
#  'timeslip': 579,
#  'aulis': 580,
#  'priority': 581,
#  'naturist': 582,
#  'litreture': 584,
#  'swore': 107,
#  'schweiger': 585,
#  'succeeded': 586,
#  'schulberg': 587,
#  'giacomo': 588,
#  'erudite': 589,
#  'montag': 591,
#  'birmingham': 592,
#  'defines': 594,
#  'humbly': 26264,
#  'gimmeclassics': 109,
#  'atkinmson': 61791,
#  'genndy': 595,
#  'contributed': 596,
#  'roles': 597,
#  'puppo': 598,
#  'usefully': 599,
#  'mcdougle': 601,
#  'catharsic': 62711,
#  'beute': 602,
#  'epidemic': 603,
#  'merlik': 604,
#  'collects': 49502,
#  'hofd': 605,
#  'lamia': 606,
#  'collectors': 607,
#  'sheri': 608,
#  'freaks': 609,
#  'spars': 610,
#  'glock': 611,
#  'ingela': 612,
#  'salutes': 114,
#  'fasso': 613,
#  'katie': 614,
#  'beginnings': 49505,
#  'previewed': 615,
#  'roladex': 616,
#  'cetnik': 617,
#  'overpopulated': 49507,
#  'dushku': 618,
#  'aparently': 12461,
#  'pole': 56568,
#  'meth': 621,
#  'endectomy': 620,
#  'exemplifying': 624,
#  'lachlin': 625,
#  'boomerangs': 626,
#  'betaab': 627,
#  'apollonian': 629,
#  'turkeys': 120,
#  'viennale': 630,
#  'volvo': 631,
#  'volptuous': 632,
#  'orphans': 633,
#  'harmonica': 634,
#  'chock': 635,
#  'davidbathsheba': 637,
#  'salmon': 638,
#  'imprisons': 640,
#  'conure': 641,
#  'idiom': 642,
#  'ilses': 643,
#  'monkey': 644,
#  'ape': 645,
#  'fantastical': 647,
#  'extroverts': 649,
#  'nuanced': 650,
#  'radius': 651,
#  'gander': 72383,
#  'rawandan': 132,
#  'invisibilation': 652,
#  'businesstiger': 654,
#  'conquerer': 37015,
#  'cinemagraphic': 62843,
#  'katch': 61807,
#  'aldonova': 655,
#  'doen': 61403,
#  'dullllllllllll': 128,
#  'sorenson': 657,
#  'kaczorowski': 129,
#  'jlh': 658,
#  'glides': 659,
#  'wood': 660,
#  'splashes': 661,
#  'unshaken': 662,
#  'downloadable': 61806,
#  'principled': 12475,
#  'sneered': 663,
#  'batteries': 664,
#  'kiosk': 72517,
#  'standout': 665,
#  'impairment': 666,
#  'dosages': 667,
#  'charlatans': 670,
#  'dupes': 671,
#  'narrators': 672,
#  'plebes': 61315,
#  'dominating': 675,
#  'contemplate': 676,
#  'horrifibly': 677,
#  'repast': 678,
#  'yeast': 679,
#  'childen': 680,
#  'clinton': 61811,
#  'maize': 682,
#  'shufflers': 71732,
#  'pappa': 47284,
#  'respite': 37021,
#  'onrunning': 683,
#  'historians': 49522,
#  'lay': 684,
#  'lordship': 685,
#  'amateuristic': 687,
#  'crushingly': 688,
#  'gymnastics': 689,
#  'wimp': 691,
#  'mecha': 693,
#  'orchestrate': 694,
#  'frenzy': 695,
#  'essentially': 42281,
#  'bear': 697,
#  'never': 698,
#  'shumlin': 37023,
#  'jovovich': 18994,
#  'discerns': 700,
#  'phantasmal': 49525,
#  'maturing': 701,
#  'psychosexually': 702,
#  'progression': 703,
#  'floats': 705,
#  'basball': 706,
#  'maybee': 707,
#  'mannu': 12480,
#  'cathie': 708,
#  'startrek': 709,
#  'consistence': 710,
#  'algy': 711,
#  'darwinian': 713,
#  'turley': 714,
#  'ratner': 24820,
#  'thanklessly': 717,
#  'monk': 716,
#  'burgermeister': 37026,
#  'taratino': 718,
#  'warwick': 719,
#  'skerritt': 722,
#  'humoran': 723,
#  'cheating': 724,
#  'fairground': 725,
#  'exhilaration': 726,
#  'mehmood': 28290,
#  'larger': 727,
#  'macgruder': 12825,
#  'haefengstal': 24823,
#  'cinematically': 728,
#  'jonathn': 729,
#  'salvador': 730,
#  'indecisiveness': 731,
#  'globally': 732,
#  'intermissions': 734,
#  'phipps': 24824,
#  'cloistering': 735,
#  'inverting': 11717,
#  'incentivized': 736,
#  'referencing': 737,
#  'squats': 738,
#  'rentals': 739,
#  'eugenic': 63786,
#  'institutionalization': 740,
#  'dahm': 741,
#  'usages': 742,
#  'fitzs': 743,
#  'relaying': 744,
#  'unproven': 70449,
#  'rom': 745,
#  'coppers': 746,
#  'imdbers': 49536,
#  'buttgereit': 747,
#  'rebuffs': 748,
#  'darth': 749,
#  'grasped': 750,
#  'healey': 751,
#  'self': 49539,
#  'deductible': 752,
#  'diana': 753,
#  'mf': 754,
#  'trina': 755,
#  'lightships': 756,
#  'nietsche': 61827,
#  'calls': 757,
#  'meola': 758,
#  'spank': 759,
#  'gores': 761,
#  'salvation': 762,
#  'madeline': 763,
#  'carnaby': 768,
#  'revolutionize': 767,
#  'violate': 766,
#  'terrify': 769,
#  'heftily': 770,
#  'weenies': 771,
#  'climacteric': 772,
#  'consider': 773,
#  'vandalised': 774,
#  'tv': 12486,
#  'gussets': 775,
#  'muttering': 776,
#  'ritualized': 782,
#  'dales': 783,
#  'airports': 784,
#  'firoz': 68058,
#  'generatively': 787,
#  'quais': 786,
#  'propel': 68303,
#  'idi': 789,
#  'sami': 58293,
#  'perked': 53452,
#  'vadar': 794,
#  'jovi': 791,
#  'sider': 792,
#  'cramming': 793,
#  'complaints': 795,
#  'defrauds': 797,
#  'cross': 798,
#  'constricted': 799,
#  'quin': 801,
#  'littttle': 42581,
#  'woofter': 802,
#  'grail': 49549,
#  'ethnically': 28037,
#  'mosters': 803,
#  'doorstop': 804,
#  'sieve': 805,
#  'titted': 806,
#  'storystick': 808,
#  'lethargy': 810,
#  'shiranui': 811,
#  'carleton': 813,
#  'repo': 61508,
#  'kik': 814,
#  'desperados': 815,
#  'calcutta': 816,
#  'khandi': 818,
#  'university': 819,
#  'creme': 820,
#  'vendor': 145,
#  'unredeemed': 821,
#  'busybodies': 825,
#  'muchchandu': 826,
#  'shuttle': 828,
#  'lala': 829,
#  'ratman': 827,
#  'scotts': 831,
#  'boogey': 832,
#  'actorsactresses': 834,
#  'todos': 837,
#  'gaspy': 838,
#  'carribien': 839,
#  'relocations': 841,
#  'afm': 844,
#  'viet': 843,
#  'wristed': 845,
#  'arrives': 12496,
#  'emits': 847,
#  'freddie': 848,
#  'congested': 849,
#  'excessively': 850,
#  'hastens': 852,
#  'charendoff': 71580,
#  'unwarranted': 853,
#  'connived': 854,
#  'spitting': 855,
#  'exploitational': 856,
#  'reposition': 858,
#  'rapidshare': 859,
#  'mabille': 860,
#  'heavenlier': 862,
#  'mchugh': 863,
#  'soha': 864,
#  'topo': 865,
#  'landlord': 71574,
#  'shriekfest': 866,
#  'beige': 65246,
#  'friday': 867,
#  'gatsby': 870,
#  'prophet': 872,
#  'gunge': 878,
#  'idiomatic': 880,
#  'classing': 879,
#  'dedicated': 875,
#  'ramala': 876,
#  'werdegast': 37055,
#  'swat': 61843,
#  'nightgowns': 882,
#  'hussle': 71121,
#  'scariness': 24841,
#  'serguis': 883,
#  'catelain': 884,
#  'bestowing': 58969,
#  'subtitling': 885,
#  'angel': 886,
#  'punisher': 887,
#  'suppressing': 61845,
#  'shao': 888,
#  'corrigan': 889,
#  'fantasticfantasticfantastic': 24848,
#  'sisterly': 890,
#  'arcades': 891,
#  'satisfy': 51964,
#  'nerdbomber': 892,
#  'volkswagen': 893,
#  'owes': 894,
#  'shaye': 56636,
#  'playback': 24846,
#  'phantom': 896,
#  'speaking': 897,
#  'nudes': 899,
#  'panelling': 903,
#  'mayan': 901,
#  'bagpipes': 44554,
#  'plumbers': 904,
#  'colonisation': 62037,
#  'josip': 906,
#  'manliness': 907,
#  'devises': 909,
#  'canton': 910,
#  'thatwell': 911,
#  'attonment': 913,
#  'parters': 914,
#  'hana': 915,
#  'macquire': 917,
#  'chauffeurs': 918,
#  'maimed': 919,
#  'soppiness': 920,
#  'undated': 921,
#  'suggestible': 922,
#  'imaginations': 64184,
#  'destroyer': 923,
#  'snl': 924,
#  'targeting': 925,
#  'bassinger': 926,
#  'fancying': 928,
#  'erroneous': 57867,
#  'kingpin': 929,
#  'hitchcok': 930,
#  'seers': 931,
#  'fou': 932,
#  'leith': 933,
#  'lollobrigidamiaoooou': 934,
#  'raymie': 935,
#  'maleficent': 938,
#  'inexactitudes': 937,
#  'akroyd': 37065,
#  'truely': 939,
#  'lavishly': 940,
#  'regis': 941,
#  'organizers': 942,
#  'flicker': 943,
#  'blessings': 72527,
#  'backula': 944,
#  'pontente': 945,
#  'fillings': 946,
#  'campyness': 947,
#  'jugoslavia': 67654,
#  'incites': 948,
#  'wichita': 162,
#  'bentivoglio': 949,
#  'devotional': 61859,
#  'deserved': 950,
#  'bookended': 951,
#  'tune': 952,
#  'sustaining': 953,
#  'jointed': 954,
#  'broiling': 955,
#  'mongolian': 30570,
#  'observing': 956,
#  'jaded': 957,
#  'martyrdom': 37069,
#  'batmobile': 67099,
#  'serrat': 958,
#  'criterion': 959,
#  'shaka': 960,
#  'animitronics': 961,
#  'joystick': 962,
#  'tumultuous': 963,
#  'skinning': 964,
#  'recognised': 965,
#  'cartooning': 966,
#  'austrailian': 967,
#  'kuo': 971,
#  'commodus': 969,
#  'hog': 970,
#  'identify': 37072,
#  'emulating': 49571,
#  'inbreeds': 972,
#  'noe': 973,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    
    # TODO: count how many times each word is used in the given review and store the results in layer_0 
    for word in str.split(review):
        layer_0[0,word2index[word]] += 1

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
hot_indices = [ind for ind, x in enumerate(layer_0[0]) if x!=0]
print(hot_indices)
print(reviews[0])
for ind in hot_indices:
    hot_word = list(word2index.keys())[list(word2index.values()).index(ind)]
    print(hot_word, "--Found In Review" if hot_word in str.split(reviews[0]) else "WRONG!!")
# Out:
# [545, 4196, 4688, 4902, 6311, 6709, 7113, 8712, 8731, 9971, 12449, 13907, 14538, 16411, 17117, 17349, 18633, 19080, 19117, 19474, 20247, 20316, 22454, 22886, 23350, 23671, 23794, 24486, 25041, 25060, 25653, 27519, 27539, 28749, 30327, 30993, 31110, 31221, 32053, 32657, 33144, 35193, 35973, 36988, 39380, 39914, 41516, 41922, 42776, 44049, 44614, 45594, 46040, 47610, 47945, 48194, 48351, 48666, 50940, 51873, 53211, 53420, 55693, 56763, 56865, 56932, 58311, 58599, 59590, 59930, 60384, 61931, 62026, 62134, 63927, 64817, 65384, 65763, 66441, 66461, 67766, 67956, 68008, 68111, 68131, 69017, 70124, 70131, 70913, 71237, 72748, 73160]
# bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t
# classic --Found In Review
# fetched --Found In Review
# isn --Found In Review
# is --Found In Review
# repeatedly --Found In Review
# about --Found In Review
# pity --Found In Review
# much --Found In Review
# pettiness --Found In Review
# tried --Found In Review
# far --Found In Review
# situation --Found In Review
# t --Found In Review
# such --Found In Review
# closer --Found In Review
# when --Found In Review
# immediately --Found In Review
# lead --Found In Review
# ran --Found In Review
# cartoon --Found In Review
# to --Found In Review
# time --Found In Review
# burn --Found In Review
# reality --Found In Review
# pomp --Found In Review
# financially --Found In Review
# saw --Found In Review
# life --Found In Review
# same --Found In Review
# insightful --Found In Review
# teachers --Found In Review
# their --Found In Review
# which --Found In Review
# my --Found In Review
# survive --Found In Review
# in --Found In Review
# recalled --Found In Review
# can --Found In Review
# schools --Found In Review
# down --Found In Review
# s --Found In Review
# it --Found In Review
# some --Found In Review
# right --Found In Review
# many --Found In Review
# who --Found In Review
# high --Found In Review
# pathetic --Found In Review
# years --Found In Review
# all --Found In Review
# adults --Found In Review
# me --Found In Review
# of --Found In Review
# sack --Found In Review
# think --Found In Review
# expect --Found In Review
# profession --Found In Review
# satire --Found In Review
# programs --Found In Review
# what --Found In Review
# welcome --Found In Review
# student --Found In Review
# your --Found In Review
# . --Found In Review
# scramble --Found In Review
# i --Found In Review
# through --Found In Review
# that --Found In Review
# at --Found In Review
# knew --Found In Review
# and --Found In Review
# age --Found In Review
# comedy --Found In Review
# the --Found In Review
# here --Found In Review
# a --Found In Review
# than --Found In Review
# bromwell --Found In Review
# one --Found In Review
# teaching --Found In Review
# inspector --Found In Review
# line --Found In Review
# episode --Found In Review
# m --Found In Review
# remind --Found In Review
# students --Found In Review
# other --Found In Review
# whole --Found In Review
# see --Found In Review
# as --Found In Review
# school --Found In Review
# believe --Found In Review

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    if label == "POSITIVE":
        return 1
    return 0

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        # TODO: populate review_vocab with all of the words in the given reviews
        #       Remember to split reviews into individual words 
        #       using "split(' ')" instead of "split()".
        
        for rev in reviews:
            for word in str.split(rev):
                review_vocab.add(word)
        
        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        # TODO: populate label_vocab with all of the words in the given labels.
        #       There is no need to split the labels because each one is a single word.
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        # TODO: populate self.word2index with indices for all the words in self.review_vocab
        #       like you saw earlier in the notebook
        for ind, word in enumerate(self.review_vocab):
            self.word2index[word] = ind
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        # TODO: do the same thing you did for self.word2index and self.review_vocab, 
        #       but for self.label2index and self.label_vocab instead
        for ind, word in enumerate(self.label_vocab):
            self.label2index[word] = ind
            
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Store the number of nodes in input, hidden, and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights
        
        # TODO: initialize self.weights_0_1 as a matrix of zeros. These are the weights between
        #       the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
        # TODO: initialize self.weights_1_2 as a matrix of random values. 
        #       These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.random((self.hidden_nodes,self.output_nodes))-.5
        # TODO: Create the input layer, a two-dimensional matrix with shape 
        #       1 x input_nodes, with all values initialized to zero
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):
        self.layer_0 *= 0
        for word in str.split(review):
            if word in self.review_vocab:
                self.layer_0[0,self.word2index[word]] += 1
        
                
    def get_target_for_label(self,label): 
        if label == "POSITIVE":
            return 1
        return 0
        
    def sigmoid(self,x):
        return 1/(1+np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        # TODO: Return the derivative of the sigmoid activation function, 
        #       where "output" is the original output from the sigmoid fucntion 
        return output*(1-output)

    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            # TODO: Get the next review and its correct label
            rev = training_reviews[i]
            lab = training_labels[i]
            
                  
            # TODO: Implement the forward pass through the network. 
            #       That means use the given review to update the input layer, 
            #       then calculate values for the hidden layer,
            #       and finally calculate the output layer.
            # 
            #       Do not use an activation function for the hidden layer,
            #       but use the sigmoid activation function for the output layer.
            self.update_input_layer(rev)
            hidden_output = np.dot(self.layer_0,self.weights_0_1)
            
            final_output = self.sigmoid(np.dot(hidden_output,self.weights_1_2))
                  
            # TODO: Implement the back propagation pass here. 
            #       That means calculate the error for the forward pass's prediction
            #       and update the weights in the network according to their
            #       contributions toward the error, as calculated via the
            #       gradient descent and back propagation algorithms you 
            #       learned in class.
            err_val = get_target_for_label(lab) - final_output
                  
            output_error_term = err_val * self.sigmoid_output_2_derivative(final_output)
            
            
            hidden_error = np.dot(output_error_term, self.weights_1_2.T)
            hidden_error_term = hidden_error
            
            self.weights_1_2 += self.learning_rate * output_error_term*hidden_output.T
            self.weights_0_1 += self.learning_rate * hidden_error_term*self.layer_0.T
            
            # TODO: Keep track of correct predictions. To determine if the prediction was
            #       correct, check that the absolute value of the output error 
            #       is less than 0.5. If so, add one to the correct_so_far count.
            if np.absolute(err_val) < .5:
                  correct_so_far += 1
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
    
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%" \
                             + " Error: "+str(err_val))
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # TODO: Run a forward pass through the network, like you did in the
        #       "train" function. That means use the given review to 
        #       update the input layer, then calculate values for the hidden layer,
        #       and finally calculate the output layer.
        #
        #       Note: The review passed into this function for prediction 
        #             might come from anywhere, so you should convert it 
        #             to lower case prior to using it.
        
        # TODO: The output layer should now contain a prediction. 
        #       Return `POSITIVE` for predictions greater-than-or-equal-to `0.5`, 
        #       and `NEGATIVE` otherwise
        self.update_input_layer(review)
        hidden_output = np.dot(self.layer_0,self.weights_0_1)
        final_output = self.sigmoid(np.dot(hidden_output,self.weights_1_2))
        if final_output >= .5:
            return 'POSITIVE'
        return 'NEGATIVE'

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):2.674 #Correct:500 #Tested:1000 Testing Accuracy:50.0%

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0% Error: [[ 0.5]]
# Progress:0.14% Speed(reviews/sec):2.932 #Correct:13 #Trained:36 Training Accuracy:36.1% Error: [[-0.58944956]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-194-a5b7efd2dc8f> in <module>()
# ----> 1 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-192-698564ca056e> in train(self, training_reviews, training_labels)
#     137             #       Do not use an activation function for the hidden layer,
#     138             #       but use the sigmoid activation function for the output layer.
# --> 139             self.update_input_layer(rev)
#     140             hidden_output = np.dot(self.layer_0,self.weights_0_1)
#     141
#
# <ipython-input-192-698564ca056e> in update_input_layer(self, review)
#      94         self.layer_0 *= 0
#      95         for word in str.split(review):
# ---> 96             if word in self.review_vocab:
#      97                 self.layer_0[0,self.word2index[word]] += 1
#      98
#
# KeyboardInterrupt:

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0% Error: [[ 0.5]]
# Progress:2.74% Speed(reviews/sec):2.627 #Correct:350 #Trained:659 Training Accuracy:53.1% Error: [[ 0.58730738]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-195-ae7da216e940> in <module>()
#       1 mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
# ----> 2 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-192-698564ca056e> in train(self, training_reviews, training_labels)
#     137             #       Do not use an activation function for the hidden layer,
#     138             #       but use the sigmoid activation function for the output layer.
# --> 139             self.update_input_layer(rev)
#     140             hidden_output = np.dot(self.layer_0,self.weights_0_1)
#     141
#
# <ipython-input-192-698564ca056e> in update_input_layer(self, review)
#      94         self.layer_0 *= 0
#      95         for word in str.split(review):
# ---> 96             if word in self.review_vocab:
#      97                 self.layer_0[0,self.word2index[word]] += 1
#      98
#
# KeyboardInterrupt:

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0% Error: [[ 0.5]]
# Progress:1.35% Speed(reviews/sec):2.451 #Correct:164 #Trained:327 Training Accuracy:50.1% Error: [[ 0.55574569]]

# %% [markdown]
# With a learning rate of `0.001`, the network should finall have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
